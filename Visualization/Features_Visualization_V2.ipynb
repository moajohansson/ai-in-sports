# %%
# import statements

import pandas as pd
import numpy as np
import math
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from pandas import Series

from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, BatchNormalization

from sklearn.model_selection import train_test_split
from random import shuffle

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
# Out:
# /Users/nickeylawrence/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Read the Gear2 data
X2_Gear2 = pd.read_csv('./Gear2/segment2.csv');
Y2_Gear2 = pd.DataFrame(data= np.full((X2_Gear2.shape[0],1), 2));
X2_Gear2 = X2_Gear2.assign(Gear=Y2_Gear2.values);
 
X3_Gear2 = pd.read_csv('./Gear2/segment3.csv');
Y3_Gear2 = pd.DataFrame(data= np.full((X3_Gear2.shape[0],1), 2));
X3_Gear2 = X3_Gear2.assign(Gear=Y3_Gear2.values);

X4_Gear2 = pd.read_csv('./Gear2/segment4.csv');
Y4_Gear2 = pd.DataFrame(data= np.full((X4_Gear2.shape[0],1), 2));
X4_Gear2 = X4_Gear2.assign(Gear=Y4_Gear2.values);

X5_Gear2 = pd.read_csv('./Gear2/segment5.csv');
Y5_Gear2 = pd.DataFrame(data= np.full((X5_Gear2.shape[0],1), 2));
X5_Gear2 = X5_Gear2.assign(Gear=Y5_Gear2.values);

X6_Gear2 = pd.read_csv('./Gear2/segment6.csv');
Y6_Gear2 = pd.DataFrame(data= np.full((X6_Gear2.shape[0],1), 2));
X6_Gear2 = X6_Gear2.assign(Gear=Y6_Gear2.values);


# Read the Gear3 data
X1_Gear3 = pd.read_csv('./Gear3/segment1.csv');
Y1_Gear3 = pd.DataFrame(data= np.full((X1_Gear3.shape[0],1), 3));
X1_Gear3 = X1_Gear3.assign(Gear=Y1_Gear3.values);

X2_Gear3 = pd.read_csv('./Gear3/segment2.csv');
Y2_Gear3 = pd.DataFrame(data= np.full((X2_Gear3.shape[0],1), 3));
X2_Gear3 = X2_Gear3.assign(Gear=Y2_Gear3.values);

X3_Gear3 = pd.read_csv('./Gear3/segment3.csv');
Y3_Gear3 = pd.DataFrame(data= np.full((X3_Gear3.shape[0],1), 3));
X3_Gear3 = X3_Gear3.assign(Gear=Y3_Gear3.values);

X4_Gear3 = pd.read_csv('./Gear3/segment4.csv');
Y4_Gear3 = pd.DataFrame(data= np.full((X4_Gear3.shape[0],1), 3));
X4_Gear3 = X4_Gear3.assign(Gear=Y4_Gear3.values);

X5_Gear3 = pd.read_csv('./Gear3/segment5.csv');
Y5_Gear3 = pd.DataFrame(data= np.full((X5_Gear3.shape[0],1), 3));
X5_Gear3 = X5_Gear3.assign(Gear=Y5_Gear3.values);

X6_Gear3 = pd.read_csv('./Gear3/segment6.csv');
Y6_Gear3 = pd.DataFrame(data= np.full((X6_Gear3.shape[0],1), 3));
X6_Gear3 = X6_Gear3.assign(Gear=Y6_Gear3.values);


# Read the Gear4 data
X2_Gear4 = pd.read_csv('./Gear4/segment2.csv');
Y2_Gear4 = pd.DataFrame(data= np.full((X2_Gear4.shape[0],1), 4));
X2_Gear4 = X2_Gear4.assign(Gear=Y2_Gear4.values);

X3_Gear4 = pd.read_csv('./Gear4/segment3.csv');
Y3_Gear4 = pd.DataFrame(data= np.full((X3_Gear4.shape[0],1), 4));
X3_Gear4 = X3_Gear4.assign(Gear=Y3_Gear4.values);

X4_Gear4 = pd.read_csv('./Gear4/segment4.csv');
Y4_Gear4 = pd.DataFrame(data= np.full((X4_Gear4.shape[0],1), 4));
X4_Gear4 = X4_Gear4.assign(Gear=Y4_Gear4.values);

X5_Gear4 = pd.read_csv('./Gear4/segment5.csv');
Y5_Gear4 = pd.DataFrame(data= np.full((X5_Gear4.shape[0],1), 4));
X5_Gear4 = X5_Gear4.assign(Gear=Y5_Gear4.values);

X6a_Gear4 = pd.read_csv('./Gear4/segment6a.csv');
Y6a_Gear4 = pd.DataFrame(data= np.full((X6a_Gear4.shape[0],1), 4));
X6a_Gear4 = X6a_Gear4.assign(Gear=Y6a_Gear4.values);

X6b_Gear4 = pd.read_csv('./Gear4/segment6b.csv')
Y6b_Gear4 = pd.DataFrame(data= np.full((X6b_Gear4.shape[0],1), 4));
X6b_Gear4 = X6b_Gear4.assign(Gear=Y6b_Gear4.values);


# Read the Gear5 data
X1_Gear5 = pd.read_csv('./Double/segment1.csv');
Y1_Gear5 = pd.DataFrame(data= np.full((X1_Gear5.shape[0],1), 5));
X1_Gear5 = X1_Gear5.assign(Gear=Y1_Gear5.values);

X2_Gear5 = pd.read_csv('./Double/segment2.csv');
Y2_Gear5 = pd.DataFrame(data= np.full((X2_Gear5.shape[0],1), 5));
X2_Gear5 = X2_Gear5.assign(Gear=Y2_Gear5.values);

X3_Gear5 = pd.read_csv('./Double/segment3.csv');
Y3_Gear5 = pd.DataFrame(data= np.full((X3_Gear5.shape[0],1), 5));
X3_Gear5 = X3_Gear5.assign(Gear=Y3_Gear5.values);

X4_Gear5 = pd.read_csv('./Double/segment4.csv');
Y4_Gear5 = pd.DataFrame(data= np.full((X4_Gear5.shape[0],1), 5));
X4_Gear5 = X4_Gear5.assign(Gear=Y4_Gear5.values);

X5_Gear5 = pd.read_csv('./Double/segment5.csv');
Y5_Gear5 = pd.DataFrame(data= np.full((X5_Gear5.shape[0],1), 5));
X5_Gear5 = X5_Gear5.assign(Gear=Y5_Gear5.values);

X6_Gear5 = pd.read_csv('./Double/segment7.csv');
Y6_Gear5 = pd.DataFrame(data= np.full((X6_Gear5.shape[0],1), 5));
X6_Gear5 = X6_Gear5.assign(Gear=Y6_Gear5.values);

# %%
# for i in range(len(X2_Gear2)):
#     print ('SFBSHHSÓBSGBRS')
#     startTime = i*750
#     endTime = i*750 + 750
#     print(X2_Gear2[startTime:endTime])

limit = 750


gearRange = math.ceil(len(X2_Gear2)/limit)
XGear = [X2_Gear2[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X3_Gear2)/limit)
XGear+=[X3_Gear2[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X4_Gear2)/limit)
XGear+=[X4_Gear2[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X5_Gear2)/limit)
XGear+=[X5_Gear2[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X6_Gear2)/limit)
XGear+=[X6_Gear2[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X1_Gear3)/limit)
XGear+=[X1_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X2_Gear3)/limit)
XGear+=[X2_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X3_Gear3)/limit)
XGear+=[X3_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X4_Gear3)/limit)
XGear+=[X4_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X5_Gear3)/limit)
XGear+=[X5_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X6_Gear3)/limit)
XGear+=[X6_Gear3[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X2_Gear4)/limit)
XGear+=[X2_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X3_Gear4)/limit)
XGear+=[X3_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X4_Gear4)/limit)
XGear+=[X4_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X5_Gear4)/limit)
XGear+=[X5_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X6a_Gear4)/limit)
XGear+=[X6a_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X6b_Gear4)/limit)
XGear+=[X6b_Gear4[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X1_Gear5)/limit)
XGear+=[X1_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X2_Gear5)/limit)
XGear+=[X2_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X3_Gear5)/limit)
XGear+=[X3_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X4_Gear5)/limit)
XGear+=[X4_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X5_Gear5)/limit)
XGear+=[X5_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

gearRange = math.ceil(len(X6_Gear5)/limit)
XGear+=[X6_Gear5[t*limit:t*limit + limit] for t in range(gearRange)]

# %%
X = XGear[:] # Copy words
shuffle(X) 
# print(X)

# %%
X = pd.concat(X);

# %%
data = pd.DataFrame(X);

data.reset_index(inplace = True, drop = True)
for i in range(len(data)):
    data.loc[i,'t'] = i*0.02

# data.set_index('t', inplace=True);

# %%
# Normalisation
# Feature normalization
# Normalize Time Series Data
# Source : https://machinelearningmastery.com/normalize-standardize-time-series-data-python/

# Normalization is a rescaling of the data from the original range so that all values are within the range of 0 and 1.
# useful when your time series data has input values with differing scales.
features = list(data.columns);
scaledFeatures = [item for item in features if item not in ['t','Gear']]
print(scaledFeatures)
for i in range(len(scaledFeatures)):
    feature = scaledFeatures[i];
    print('Scaling feature : ', scaledFeatures[i])
    values = X[feature].values.reshape(-1,1);
    values = values.astype('float32');
    scaler = MinMaxScaler(feature_range = (0,1));
    scaled_f = scaler.fit_transform(values);
    X[feature] = scaled_f;
# Out:
# ['fL', 'thL', 'w1L', 'w2L', 'w3L', 'a1L', 'a2L', 'a3L', 'fR', 'thR', 'w1R', 'w2R', 'w3R', 'a1R', 'a2R', 'a3R', 'x', 'y', 'v', 'vdir']
# Scaling feature :  fL
# Scaling feature :  thL
# Scaling feature :  w1L
# Scaling feature :  w2L
# Scaling feature :  w3L
# Scaling feature :  a1L
# Scaling feature :  a2L
# Scaling feature :  a3L
# Scaling feature :  fR
# Scaling feature :  thR
# Scaling feature :  w1R
# Scaling feature :  w2R
# Scaling feature :  w3R
# Scaling feature :  a1R
# Scaling feature :  a2R
# Scaling feature :  a3R
# Scaling feature :  x
# Scaling feature :  y
# Scaling feature :  v
# Scaling feature :  vdir

# %%
# Visulaization after normalization

# Histogram
print('Histogram');
data[features].hist(figsize = (20,10));
pyplot.show()

# specify columns to plot
groups = [i for i in range(20)];
values = data.values;
i = 1
# plot each column
print('Plotting each feature(column)');
pyplot.figure(figsize = (15,40))
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(data.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show();
# Out:
# Histogram
# Plotting each feature(column)

# %%
# Feature importance is one method to help sort out what might be more useful in when modeling.

# load data
array = data.values

# split into input and output
X = array[:,1:-1]
y = array[:,-1]

# fit random forest model
model = RandomForestRegressor(n_estimators=500, random_state=1)
model.fit(X, y)

# show importance scores
print(model.feature_importances_)
# Out:
# [0.01215492 0.00536038 0.00349695 0.00162463 0.00431391 0.00350694
#  0.00359238 0.00341294 0.0281801  0.01541174 0.00184768 0.00167215
#  0.00266067 0.00125908 0.00483337 0.00334847 0.37790075 0.14848341
#  0.14783181 0.22910773]

# %%
# plot importance scores
names = data.columns.values[1:-1]
print(names)
ticks = [i for i in range(len(names))]
plt.bar(ticks, model.feature_importances_)
plt.xticks(ticks, names)
plt.show()
# Out:
# ['fL' 'thL' 'w1L' 'w2L' 'w3L' 'a1L' 'a2L' 'a3L' 'fR' 'thR' 'w1R' 'w2R'
#  'w3R' 'a1R' 'a2R' 'a3R' 'x' 'y' 'v' 'vdir']
