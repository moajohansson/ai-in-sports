# %% [markdown]
# In this notebook diffrent parameters are tested, inorder to find a optimal choice of parameters for an LSTM network with respect to validation preformence. The traing data and the validation data contains samples form skier 1, 2, 3.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import math
import keras
from random import shuffle
from keras.models import Sequential, Model
from keras.layers import Dense,Bidirectional
from keras.layers import LSTM, Flatten, Input
from keras.layers import BatchNormalization
from keras.layers import TimeDistributed, Conv1D, Conv2D, MaxPooling1D, GlobalMaxPooling1D,Dropout
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.
# /Users/mariekorneliusson/anaconda3/envs/dml/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
path = os.path.normpath('/Users/mariekorneliusson/documents/AiSports/Strike_Data_As_Np')

# %%
X_First = np.load(path + '/' + 'X_First_Skier.npy')
Y_First = np.load(path + '/' + 'Y_First_Skier.npy')
feature_list_First = []
with open(path + "/keys_First_Skier.txt", "r") as f:
      for line in f:
        feature_list_First.append(line.strip('\n'))

# %%
X_Second = np.load(path + '/' + 'X_Second_Skier.npy')
Y_Second = np.load(path + '/' + 'Y_Second_Skier.npy')
feature_list_Second = []
with open(path + "/keys_Second_Skier.txt", "r") as f:
      for line in f:
        feature_list_Second.append(line.strip('\n'))

# %%
X_Third = np.load(path + '/' + 'X_Third_Skier.npy')
Y_Third = np.load(path + '/' + 'Y_Third_Skier.npy')
feature_list_Third = []
with open(path + "/keys_Third_Skier.txt", "r") as f:
      for line in f:
        feature_list_Third.append(line.strip('\n'))

# %%
feature_Dict = {i:feature_list_Second[i] for i in range(len(feature_list_Second)-1)}
print(len(feature_Dict))
# Out:
# 17

# %%
print(X_First.shape)
print(X_Second.shape)
print(X_Third.shape)
print(Y_First.shape)
print(Y_Second.shape)
print(Y_Third.shape)
# Out:
# (452, 140, 22)
# (382, 140, 18)
# (844, 140, 22)
# (452, 4)
# (382, 4)
# (844, 4)

# %%
def split_to_test_train_data(X_List,Y_List,ratio,time_step,dimX,nbr_of_classes):
    
    nbr_of_data = len(X_List)
    min_samples = min([x.shape[0] for x in X_List])
    h = int((1-ratio)*min_samples)
    nbr_of_test = [x.shape[0]-h for x in X_List]
    X = np.zeros((h*nbr_of_data,time_step,dimX))
    Y = np.zeros((h*nbr_of_data,nbr_of_classes))
    X_Test_List = [np.zeros((sum(nbr_of_test),time_step,dimX))]
    Y_Test_List = [np.zeros((sum(nbr_of_test),nbr_of_classes))]
    
    for i in range(nbr_of_data):
        x_d = np.zeros((nbr_of_test[i],time_step,dimX))
        y_d = np.zeros((nbr_of_test[i],nbr_of_classes))
        X_Test_List.append(x_d)
        Y_Test_List.append(y_d)

    test_samp_prev = 0 
    for i in range(nbr_of_data):
        x = X_List[i][:,:,:dimX]
        y = Y_List[i]
        test_samp = nbr_of_test[i] + test_samp_prev
        X[h*i:h*(i+1),:,:] = x[:h,:,:]
        Y[h*i:h*(i+1),:] = y[:h,:]
        X_Test_List[0][test_samp_prev:test_samp,:,:] = x[h:,:,:]
        Y_Test_List[0][test_samp_prev:test_samp,:] = y[h:,:]
        X_Test_List[i+1] = x[h:,:,:]
        Y_Test_List[i+1] = y[h:,:]
        test_samp_prev = test_samp
        
    return X,Y,X_Test_List,Y_Test_List

# %%
dim_X = len(feature_Dict)
X_List = [X_First,X_Second,X_Third]
Y_List = [Y_First,Y_Second,Y_Third]
ratio = 0.2
time_step = 140
nbr_of_classes = 4
X,Y,X_Test_List,Y_Test_List = split_to_test_train_data(X_List,Y_List,ratio,time_step,dim_X,nbr_of_classes)
X_Test = X_Test_List[0]
Y_Test = Y_Test_List[0]

# %%
print(X.shape)
print(Y.shape)
print(X_Test.shape)
print(Y_Test.shape)
# Out:
# (915, 140, 17)
# (915, 4)
# (763, 140, 17)
# (763, 4)

# %%
def get_strike(strike,strike_l,pad):
    
    for j in range(strike_l-3):
        if strike[j,1] == strike[j+1,1] == strike[j+2,1] == pad:
            plot_strike = strike[0:j-1,1]
            time_strike = strike[0:j-1,0]
            break
        elif strike[strike_l-2,0] > 0:
            plot_strike = strike[:,1]
            time_strike = strike[:,0]
            break
    
    return plot_strike,time_strike

# %%
def change_time_axis_for_plot(X,delta_t):
    
    nbr_of_samples = X.shape[0]
    t = 0
    for i in range(nbr_of_samples):
        for j in range(140):
            X[i,j,0] = t*delta_t
            t = t + 1
    
    return X

# %%
def plot_skiedata(true_Y,X,figure):

    nbr_of_classes = 4
    colorDict = {0:'r',1:'fuchsia',2:'deeppink',3:'orange'}
    nameDict = {0:'Gear 2',1:'Gear 3',2:'Gear 4',3:'Double','Gear 2':0,'Gear 3':1,'Gear 4':2,'Double':3}
    nbr_of_test = X.shape[0]
    strike_l = X.shape[1]
    pad = 0

    for c in range(nbr_of_classes):
        true_c = np.where(true_Y == c)[0]
        strike_true = []
        strike_pred = []
        time_true = []
        time_pred = []
        for i in range(true_c.shape[0]):
            strike = X[true_c[i],:,:]
            t_strike,t_time = get_strike(strike,strike_l,pad)
            strike_true.extend(t_strike)
            time_true.extend(t_time)

        plt.figure(figure,figsize=(15, 4))
        plt.title('True gear')
        plt.scatter(time_true,strike_true,label = 'True class: ' + nameDict[c],color =  colorDict[c], alpha = 1)
        plt.legend()
        #plt.axis([280, 320, 0, 400])
    figure = figure + 1
    return figure

# %%
delta_t = 0.02
X = change_time_axis_for_plot(X,delta_t)
X_Test = change_time_axis_for_plot(X_Test,delta_t)

# %%
true_Y = np.argmax(Y,axis = 1)
figure = plot_skiedata(true_Y,X,0)

# %%
def BLSTM_Two_Dense_26():
    
    sequence_input = Input(shape=(time_step,dim_X-1))
    x = Bidirectional(LSTM(26,return_sequences=True))(sequence_input)
    x = Dense(X.shape[1], activation='relu')(x)
    x = Flatten()(x)
    preds = Dense(nbr_of_classes, activation='softmax')(x)
    model = Model(sequence_input, preds)
    model.compile(Adam(lr=0.0001),loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

def BLSTM_Two_Dense_64():
    
    sequence_input = Input(shape=(time_step,dim_X-1))
    x = Bidirectional(LSTM(64,return_sequences=True))(sequence_input)
    x = Dense(X.shape[1], activation='relu')(x)
    x = Flatten()(x)
    preds = Dense(nbr_of_classes, activation='softmax')(x)
    model = Model(sequence_input, preds)
    model.compile(Adam(lr=0.0001),loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

def BLSTM_Two_Dense_126():
    
    sequence_input = Input(shape=(time_step,dim_X-1))
    x = Bidirectional(LSTM(26,return_sequences=True))(sequence_input)
    x = Dense(X.shape[1], activation='relu')(x)
    x = Flatten()(x)
    preds = Dense(nbr_of_classes, activation='softmax')(x)
    model = Model(sequence_input, preds)
    model.compile(Adam(lr=0.0001),loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model_names = ['BLSTM_Two_Dense_26','BLSTM_Two_Dense_64','BLSTM_Two_Dense_126']
eS = EarlyStopping(monitor='acc', min_delta=0.00001, patience=5)
i = 0
for name in model_names:
    print('Training model:',name)
    model = globals()[name]()
    #tb = TensorBoard(log_dir='./logs/'+name)
    history = model.fit(X[:,:,1:], Y, epochs=20, batch_size=1, validation_data=(X_Test[:,:,1:],Y_Test),shuffle = True,callbacks = [eS])
    print('Done!')
    plt.figure(2*i,[15,5])
    plt.title('Loss Training model: ' + name)
    plt.plot(history.history['loss'],label = 'Training loss')
    plt.plot(history.history['val_loss'],label = 'Validation loss')
    plt.legend()
    plt.figure(2*i + 1,[15,5])
    plt.plot(history.history['acc'],label = 'Training accuracy')
    plt.plot(history.history['val_acc'],label = 'Validation accuracy')
    plt.title('Accuracy Training model: ' + name)
    plt.legend()
    plt.figure(2*len(model_names),[15,5])
    plt.title('Loss')
    plt.plot(history.history['loss'],label = name)
    plt.legend()
    plt.figure(2*len(model_names) + 1,[15,5])
    plt.title('Val Loss')
    plt.plot(history.history['val_loss'],label = name)
    plt.legend()

    i = i + 1
# Out:
# Training model: BLSTM_Two_Dense_26
# Train on 915 samples, validate on 763 samples
# Epoch 1/20
# 915/915 [==============================] - 247s 269ms/step - loss: 0.5819 - acc: 0.7727 - val_loss: 0.4371 - val_acc: 0.8270
# Epoch 2/20
# 915/915 [==============================] - 218s 239ms/step - loss: 0.2578 - acc: 0.9126 - val_loss: 0.3186 - val_acc: 0.8702
# Epoch 3/20
# 915/915 [==============================] - 219s 240ms/step - loss: 0.1383 - acc: 0.9617 - val_loss: 0.2789 - val_acc: 0.8847
# Epoch 4/20
# 915/915 [==============================] - 230s 251ms/step - loss: 0.0817 - acc: 0.9825 - val_loss: 0.3056 - val_acc: 0.8834
# Epoch 5/20
# 915/915 [==============================] - 232s 254ms/step - loss: 0.0476 - acc: 0.9923 - val_loss: 0.2409 - val_acc: 0.9030
# Epoch 6/20
# 915/915 [==============================] - 223s 243ms/step - loss: 0.0292 - acc: 0.9967 - val_loss: 0.2837 - val_acc: 0.8978
# Epoch 7/20
# 915/915 [==============================] - 220s 240ms/step - loss: 0.0177 - acc: 0.9978 - val_loss: 0.3025 - val_acc: 0.8978
# Epoch 8/20
# 915/915 [==============================] - 217s 237ms/step - loss: 0.0110 - acc: 0.9978 - val_loss: 0.2827 - val_acc: 0.8978
# Epoch 9/20
# 915/915 [==============================] - 213s 233ms/step - loss: 0.0065 - acc: 0.9978 - val_loss: 0.2579 - val_acc: 0.9069
# Epoch 10/20
# 915/915 [==============================] - 231s 253ms/step - loss: 0.0038 - acc: 0.9978 - val_loss: 0.2746 - val_acc: 0.9069
# Epoch 11/20
# 915/915 [==============================] - 219s 239ms/step - loss: 0.0025 - acc: 0.9978 - val_loss: 0.3158 - val_acc: 0.9069
# Epoch 12/20
# 915/915 [==============================] - 228s 249ms/step - loss: 0.0017 - acc: 0.9978 - val_loss: 0.3714 - val_acc: 0.9004
# Done!
# Training model: BLSTM_Two_Dense_64
# Train on 915 samples, validate on 763 samples
# Epoch 1/20
# 915/915 [==============================] - 3810s 4s/step - loss: 0.5252 - acc: 0.8011 - val_loss: 0.3214 - val_acc: 0.8912
# Epoch 2/20
# 915/915 [==============================] - 210s 230ms/step - loss: 0.1937 - acc: 0.9399 - val_loss: 0.2627 - val_acc: 0.8965
# Epoch 3/20
# 915/915 [==============================] - 221s 242ms/step - loss: 0.0951 - acc: 0.9716 - val_loss: 0.2716 - val_acc: 0.8899
# Epoch 4/20
# 915/915 [==============================] - 212s 232ms/step - loss: 0.0371 - acc: 0.9945 - val_loss: 0.2811 - val_acc: 0.9017
# Epoch 5/20
# 915/915 [==============================] - 211s 230ms/step - loss: 0.0247 - acc: 0.9945 - val_loss: 0.2113 - val_acc: 0.9240
# Epoch 6/20
# 915/915 [==============================] - 209s 229ms/step - loss: 0.0125 - acc: 0.9978 - val_loss: 0.2071 - val_acc: 0.9240
# Epoch 7/20
# 915/915 [==============================] - 2093s 2s/step - loss: 0.0054 - acc: 0.9978 - val_loss: 0.2492 - val_acc: 0.9227
# Epoch 8/20
# 915/915 [==============================] - 239s 261ms/step - loss: 0.0027 - acc: 0.9978 - val_loss: 0.2534 - val_acc: 0.9174
# Epoch 9/20
# 915/915 [==============================] - 222s 243ms/step - loss: 0.0018 - acc: 0.9978 - val_loss: 0.2348 - val_acc: 0.9240
# Epoch 10/20
# 915/915 [==============================] - 215s 235ms/step - loss: 9.9038e-04 - acc: 0.9978 - val_loss: 0.2617 - val_acc: 0.9201
# Epoch 11/20
# 915/915 [==============================] - 218s 239ms/step - loss: 5.1544e-04 - acc: 0.9978 - val_loss: 0.2465 - val_acc: 0.9240
# Done!
# Training model: BLSTM_Two_Dense_126
# Train on 915 samples, validate on 763 samples
# Epoch 1/20
# 915/915 [==============================] - 217s 238ms/step - loss: 0.5679 - acc: 0.7956 - val_loss: 0.4871 - val_acc: 0.7366
# Epoch 2/20
# 915/915 [==============================] - 213s 232ms/step - loss: 0.2489 - acc: 0.9235 - val_loss: 0.3196 - val_acc: 0.8860
# Epoch 3/20
# 915/915 [==============================] - 211s 231ms/step - loss: 0.1488 - acc: 0.9563 - val_loss: 0.3312 - val_acc: 0.8611
# Epoch 4/20
# 915/915 [==============================] - 210s 229ms/step - loss: 0.0921 - acc: 0.9760 - val_loss: 0.3208 - val_acc: 0.8624
# Epoch 5/20
# 915/915 [==============================] - 401s 438ms/step - loss: 0.0562 - acc: 0.9880 - val_loss: 0.3119 - val_acc: 0.8637
# Epoch 6/20
# 915/915 [==============================] - 216s 237ms/step - loss: 0.0361 - acc: 0.9923 - val_loss: 0.2283 - val_acc: 0.9214
# Epoch 7/20
# 915/915 [==============================] - 217s 238ms/step - loss: 0.0220 - acc: 0.9978 - val_loss: 0.2461 - val_acc: 0.9004
# Epoch 8/20
# 915/915 [==============================] - 219s 239ms/step - loss: 0.0141 - acc: 0.9967 - val_loss: 0.2551 - val_acc: 0.9069
# Epoch 9/20
# 915/915 [==============================] - 229s 250ms/step - loss: 0.0087 - acc: 0.9978 - val_loss: 0.3055 - val_acc: 0.8938
# Epoch 10/20
# 915/915 [==============================] - 237s 259ms/step - loss: 0.0052 - acc: 0.9978 - val_loss: 0.2969 - val_acc: 0.9043
# Epoch 11/20
# 915/915 [==============================] - 225s 246ms/step - loss: 0.0032 - acc: 0.9978 - val_loss: 0.2777 - val_acc: 0.9122
# Epoch 12/20
# 915/915 [==============================] - 230s 251ms/step - loss: 0.0022 - acc: 0.9978 - val_loss: 0.2539 - val_acc: 0.9187
# Done!

# %%
model = BLSTM_Two_Dense_64()
eS = EarlyStopping(monitor='acc', min_delta=0.00001, patience=5)
mCp = ModelCheckpoint('BLSTM_1_2_3.h5', monitor='val_loss', save_best_only=True)
history = model.fit(X[:,:,1:], Y, epochs=20, batch_size=1, validation_data=(X_Test[:,:,1:],Y_Test),shuffle = True,callbacks = [eS,mCp])
# Out:
# Train on 915 samples, validate on 763 samples
# Epoch 1/20
# 915/915 [==============================] - 256s 280ms/step - loss: 0.5412 - acc: 0.7934 - val_loss: 0.4179 - val_acc: 0.8087
# Epoch 2/20
# 915/915 [==============================] - 251s 274ms/step - loss: 0.1828 - acc: 0.9410 - val_loss: 0.2765 - val_acc: 0.8899
# Epoch 3/20
# 915/915 [==============================] - 221s 241ms/step - loss: 0.0876 - acc: 0.9749 - val_loss: 0.2835 - val_acc: 0.8781
# Epoch 4/20
# 915/915 [==============================] - 218s 239ms/step - loss: 0.0466 - acc: 0.9880 - val_loss: 0.2703 - val_acc: 0.8938
# Epoch 5/20
# 915/915 [==============================] - 218s 238ms/step - loss: 0.0204 - acc: 0.9956 - val_loss: 0.3087 - val_acc: 0.8873
# Epoch 6/20
# 915/915 [==============================] - 219s 240ms/step - loss: 0.0127 - acc: 0.9978 - val_loss: 0.2681 - val_acc: 0.9017
# Epoch 7/20
# 915/915 [==============================] - 219s 239ms/step - loss: 0.0089 - acc: 0.9967 - val_loss: 0.2593 - val_acc: 0.9043
# Epoch 8/20
# 915/915 [==============================] - 217s 238ms/step - loss: 0.0042 - acc: 0.9978 - val_loss: 0.2582 - val_acc: 0.9135
# Epoch 9/20
# 915/915 [==============================] - 226s 247ms/step - loss: 0.0019 - acc: 0.9978 - val_loss: 0.2907 - val_acc: 0.9017
# Epoch 10/20
# 915/915 [==============================] - 248s 271ms/step - loss: 0.0010 - acc: 0.9978 - val_loss: 0.2818 - val_acc: 0.9083
# Epoch 11/20
# 915/915 [==============================] - 254s 278ms/step - loss: 6.4637e-04 - acc: 0.9978 - val_loss: 0.2611 - val_acc: 0.9201

# %%
from keras.models import load_model
model = load_model('BLSTM_1_2_3.h5')
predY = model.predict(X_Test[:,:,1:])
print(predY.shape)
pred_Y = np.argmax(predY,axis = 1)
true_Y = np.argmax(Y_Test,axis = 1)
acc = accuracy_score(true_Y,pred_Y)
print("Accuracy: %.2f" % acc)
# Out:
# (763, 4)
# Accuracy: 0.91
