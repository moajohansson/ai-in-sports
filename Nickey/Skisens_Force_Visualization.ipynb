# %% [markdown]
# ## Skisens_Force_Visualization

# %%
# import statements

import pandas as pd
import numpy as np
import math
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from pandas import Series

from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, BatchNormalization

from sklearn.model_selection import train_test_split
from random import shuffle

from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot
# Out:
# /Users/nickeylawrence/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Read the Gear2 data
X2_Gear2 = pd.read_csv('./Gear2/segment2.csv');
Y2_Gear2 = pd.DataFrame(data= np.full((X2_Gear2.shape[0],1), 2));
X2_Gear2 = X2_Gear2.assign(Gear=Y2_Gear2.values);
 
X3_Gear2 = pd.read_csv('./Gear2/segment3.csv');
Y3_Gear2 = pd.DataFrame(data= np.full((X3_Gear2.shape[0],1), 2));
X3_Gear2 = X3_Gear2.assign(Gear=Y3_Gear2.values);

X4_Gear2 = pd.read_csv('./Gear2/segment4.csv');
Y4_Gear2 = pd.DataFrame(data= np.full((X4_Gear2.shape[0],1), 2));
X4_Gear2 = X4_Gear2.assign(Gear=Y4_Gear2.values);

X5_Gear2 = pd.read_csv('./Gear2/segment5.csv');
Y5_Gear2 = pd.DataFrame(data= np.full((X5_Gear2.shape[0],1), 2));
X5_Gear2 = X5_Gear2.assign(Gear=Y5_Gear2.values);

X6_Gear2 = pd.read_csv('./Gear2/segment6.csv');
Y6_Gear2 = pd.DataFrame(data= np.full((X6_Gear2.shape[0],1), 2));
X6_Gear2 = X6_Gear2.assign(Gear=Y6_Gear2.values);


# Read the Gear3 data
X1_Gear3 = pd.read_csv('./Gear3/segment1.csv');
Y1_Gear3 = pd.DataFrame(data= np.full((X1_Gear3.shape[0],1), 3));
X1_Gear3 = X1_Gear3.assign(Gear=Y1_Gear3.values);

X2_Gear3 = pd.read_csv('./Gear3/segment2.csv');
Y2_Gear3 = pd.DataFrame(data= np.full((X2_Gear3.shape[0],1), 3));
X2_Gear3 = X2_Gear3.assign(Gear=Y2_Gear3.values);

X3_Gear3 = pd.read_csv('./Gear3/segment3.csv');
Y3_Gear3 = pd.DataFrame(data= np.full((X3_Gear3.shape[0],1), 3));
X3_Gear3 = X3_Gear3.assign(Gear=Y3_Gear3.values);

X4_Gear3 = pd.read_csv('./Gear3/segment4.csv');
Y4_Gear3 = pd.DataFrame(data= np.full((X4_Gear3.shape[0],1), 3));
X4_Gear3 = X4_Gear3.assign(Gear=Y4_Gear3.values);

X5_Gear3 = pd.read_csv('./Gear3/segment5.csv');
Y5_Gear3 = pd.DataFrame(data= np.full((X5_Gear3.shape[0],1), 3));
X5_Gear3 = X5_Gear3.assign(Gear=Y5_Gear3.values);

X6_Gear3 = pd.read_csv('./Gear3/segment6.csv');
Y6_Gear3 = pd.DataFrame(data= np.full((X6_Gear3.shape[0],1), 3));
X6_Gear3 = X6_Gear3.assign(Gear=Y6_Gear3.values);


# Read the Gear4 data
X2_Gear4 = pd.read_csv('./Gear4/segment2.csv');
Y2_Gear4 = pd.DataFrame(data= np.full((X2_Gear4.shape[0],1), 4));
X2_Gear4 = X2_Gear4.assign(Gear=Y2_Gear4.values);

X3_Gear4 = pd.read_csv('./Gear4/segment3.csv');
Y3_Gear4 = pd.DataFrame(data= np.full((X3_Gear4.shape[0],1), 4));
X3_Gear4 = X3_Gear4.assign(Gear=Y3_Gear4.values);

X4_Gear4 = pd.read_csv('./Gear4/segment4.csv');
Y4_Gear4 = pd.DataFrame(data= np.full((X4_Gear4.shape[0],1), 4));
X4_Gear4 = X4_Gear4.assign(Gear=Y4_Gear4.values);

X5_Gear4 = pd.read_csv('./Gear4/segment5.csv');
Y5_Gear4 = pd.DataFrame(data= np.full((X5_Gear4.shape[0],1), 4));
X5_Gear4 = X5_Gear4.assign(Gear=Y5_Gear4.values);

X6a_Gear4 = pd.read_csv('./Gear4/segment6a.csv');
Y6a_Gear4 = pd.DataFrame(data= np.full((X6a_Gear4.shape[0],1), 4));
X6a_Gear4 = X6a_Gear4.assign(Gear=Y6a_Gear4.values);

X6b_Gear4 = pd.read_csv('./Gear4/segment6b.csv')
Y6b_Gear4 = pd.DataFrame(data= np.full((X6b_Gear4.shape[0],1), 4));
X6b_Gear4 = X6b_Gear4.assign(Gear=Y6b_Gear4.values);


# Read the Gear5 data
X1_Gear5 = pd.read_csv('./Double/segment1.csv');
Y1_Gear5 = pd.DataFrame(data= np.full((X1_Gear5.shape[0],1), 5));
X1_Gear5 = X1_Gear5.assign(Gear=Y1_Gear5.values);

X2_Gear5 = pd.read_csv('./Double/segment2.csv');
Y2_Gear5 = pd.DataFrame(data= np.full((X2_Gear5.shape[0],1), 5));
X2_Gear5 = X2_Gear5.assign(Gear=Y2_Gear5.values);

X3_Gear5 = pd.read_csv('./Double/segment3.csv');
Y3_Gear5 = pd.DataFrame(data= np.full((X3_Gear5.shape[0],1), 5));
X3_Gear5 = X3_Gear5.assign(Gear=Y3_Gear5.values);

X4_Gear5 = pd.read_csv('./Double/segment4.csv');
Y4_Gear5 = pd.DataFrame(data= np.full((X4_Gear5.shape[0],1), 5));
X4_Gear5 = X4_Gear5.assign(Gear=Y4_Gear5.values);

X5_Gear5 = pd.read_csv('./Double/segment5.csv');
Y5_Gear5 = pd.DataFrame(data= np.full((X5_Gear5.shape[0],1), 5));
X5_Gear5 = X5_Gear5.assign(Gear=Y5_Gear5.values);

X6_Gear5 = pd.read_csv('./Double/segment7.csv');
Y6_Gear5 = pd.DataFrame(data= np.full((X6_Gear5.shape[0],1), 5));
X6_Gear5 = X6_Gear5.assign(Gear=Y6_Gear5.values);

# %%
# Plot the gear 2 segment 2 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear2 Segement 2') 
ax1.plot(X2_Gear2['t'], X2_Gear2['fL'], c ='orange')
ax2.set_title('Force Right for Gear2 Segement 2') 
ax2.plot(X2_Gear2['t'], X2_Gear2['fR'], c ='green')
# ax1.xaxis.set_ticks(np.arange(0, 28, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 200, 20))
ax2.xaxis.set_ticks(np.arange(0, 28, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 200, 20))
plt.show()



# Plot the gear 2 segment 3 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear2 Segement 3') 
ax1.plot(X3_Gear2['t'], X3_Gear2['fL'], c ='orange')
ax2.set_title('Force Right for Gear2 Segement 3') 
ax2.plot(X3_Gear2['t'], X3_Gear2['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 18, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 300, 20))
ax2.xaxis.set_ticks(np.arange(0, 18, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 300, 20))
plt.show()


# Plot the gear 2 segment 4 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear2 Segement 4') 
ax1.plot(X4_Gear2['t'], X4_Gear2['fL'], c ='orange')
ax2.set_title('Force Right for Gear2 Segement 4') 
ax2.plot(X4_Gear2['t'], X4_Gear2['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 24, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 250, 20))
ax2.xaxis.set_ticks(np.arange(0, 24, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 250, 20))
plt.show()


# Plot the gear 2 segment 5 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear2 Segement 5') 
ax1.plot(X5_Gear2['t'], X5_Gear2['fL'], c ='orange')
ax2.set_title('Force Right for Gear2 Segement 5') 
ax2.plot(X5_Gear2['t'], X5_Gear2['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 14, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 300, 20))
ax2.xaxis.set_ticks(np.arange(0, 14, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 250, 20))
plt.show()



# Plot the gear 2 segment 6 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear2 Segement 6') 
ax1.plot(X6_Gear2['t'], X6_Gear2['fL'], c ='orange')
ax2.set_title('Force Right for Gear2 Segement 6') 
ax2.plot(X6_Gear2['t'], X6_Gear2['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 28, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 200, 20))
ax2.xaxis.set_ticks(np.arange(0, 28, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 250, 20))
plt.show()

# %%
# Plot the gear 3 segment 1 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 1') 
ax1.plot(X1_Gear3['t'], X1_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 1') 
ax2.plot(X1_Gear3['t'], X1_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 400, 20))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 260, 20))
plt.show()

# Plot the gear 3 segment 2 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 2') 
ax1.plot(X2_Gear3['t'], X2_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 2') 
ax2.plot(X2_Gear3['t'], X2_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 21, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 260, 20))
ax2.xaxis.set_ticks(np.arange(0, 30, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 400, 20))
plt.show()

# Plot the gear 3 segment 3 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 3') 
ax1.plot(X3_Gear3['t'], X3_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 3') 
ax2.plot(X3_Gear3['t'], X3_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 17, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 300, 20))
ax2.xaxis.set_ticks(np.arange(0, 17, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 200, 20))
plt.show()

# Plot the gear 3 segment 4 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 4') 
ax1.plot(X4_Gear3['t'], X4_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 4') 
ax2.plot(X4_Gear3['t'], X4_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 30, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 260, 20))
ax2.xaxis.set_ticks(np.arange(0, 30, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 260, 20))
plt.show()

# Plot the gear 3 segment 5 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 5') 
ax1.plot(X5_Gear3['t'], X5_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 5') 
ax2.plot(X5_Gear3['t'], X5_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 30, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 400, 20))
ax2.xaxis.set_ticks(np.arange(0, 30, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 400, 20))
plt.show()

# Plot the gear 3 segment 6 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear3 Segement 6') 
ax1.plot(X6_Gear3['t'], X6_Gear3['fL'], c ='orange')
ax2.set_title('Force Right for Gear3 Segement 6') 
ax2.plot(X6_Gear3['t'], X6_Gear3['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 350, 20))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 500, 20))
plt.show()

# %%
# Plot the gear 4 segment 2 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear4 Segement 2') 
ax1.plot(X2_Gear4['t'], X2_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 2') 
ax2.plot(X2_Gear4['t'], X2_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 200, 20))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 300, 20))
plt.show()

# Plot the gear 4 segment 3 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45, 10))
    
ax1.set_title('Force Left for Gear4 Segement 3') 
ax1.plot(X3_Gear4['t'], X3_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 3') 
ax2.plot(X3_Gear4['t'], X3_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 27, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 260, 20))
ax2.xaxis.set_ticks(np.arange(0, 27, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 260, 20))
plt.show()

# Plot the gear 4 segment 4 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45, 10))
    
ax1.set_title('Force Left for Gear4 Segement 4') 
ax1.plot(X4_Gear4['t'], X4_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 4') 
ax2.plot(X4_Gear4['t'], X4_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 300, 20))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 400, 20))
plt.show()

# Plot the gear 4 segment 5 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45, 10))
    
ax1.set_title('Force Left for Gear4 Segement 5') 
ax1.plot(X5_Gear4['t'], X5_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 5') 
ax2.plot(X5_Gear4['t'], X5_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 16, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 300, 20))
ax2.xaxis.set_ticks(np.arange(0, 16, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 500, 20))
plt.show()

# Plot the gear 4 segment 6a force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(50,15))
    
ax1.set_title('Force Left for Gear4 Segement 6a') 
ax1.plot(X6a_Gear4['t'], X6a_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 6a') 
ax2.plot(X6a_Gear4['t'], X6a_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 12, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 250, 20))
ax2.xaxis.set_ticks(np.arange(0, 12, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 500, 20))
plt.show()

# Plot the gear 4 segment 6b force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,8))
    
ax1.set_title('Force Left for Gear4 Segement 6b') 
ax1.plot(X6b_Gear4['t'], X6b_Gear4['fL'], c ='orange')
ax2.set_title('Force Right for Gear4 Segement 6b') 
ax2.plot(X6b_Gear4['t'], X6b_Gear4['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 13, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 250, 20))
ax2.xaxis.set_ticks(np.arange(0, 13, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 250, 20))
plt.show()

# %%
# Plot the gear 5 segment 1 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45,10))
    
ax1.set_title('Force Left for Gear5 Segement 1') 
ax1.plot(X1_Gear5['t'], X1_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 1') 
ax2.plot(X1_Gear5['t'], X1_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 400, 20))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 300, 20))
plt.show()

# Plot the gear 5 segment 2 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45, 10))
    
ax1.set_title('Force Left for Gear5 Segement 2') 
ax1.plot(X2_Gear5['t'], X2_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 2') 
ax2.plot(X2_Gear5['t'], X2_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 350, 40))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 400, 20))
plt.show()


# Plot the gear 5 segment 3 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45,10))
    
ax1.set_title('Force Left for Gear5 Segement 3') 
ax1.plot(X3_Gear5['t'], X3_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 3') 
ax2.plot(X3_Gear5['t'], X3_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 14, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 450, 40))
ax2.xaxis.set_ticks(np.arange(0, 14, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 300, 20))
plt.show()

# Plot the gear 5 segment 4 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45,10))
    
ax1.set_title('Force Left for Gear5 Segement 4') 
ax1.plot(X4_Gear5['t'], X4_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 4') 
ax2.plot(X4_Gear5['t'], X4_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 600, 40))
ax2.xaxis.set_ticks(np.arange(0, 26, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 300, 20))
plt.show()

# Plot the gear 5 segment 5 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45,10))
    
ax1.set_title('Force Left for Gear5 Segement 5') 
ax1.plot(X5_Gear5['t'], X5_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 5') 
ax2.plot(X5_Gear5['t'], X5_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 15, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 480, 20))
ax2.xaxis.set_ticks(np.arange(0, 15, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 480, 20))
plt.show()

# Plot the gear 5 segment 7 force data

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(45,10))
    
ax1.set_title('Force Left for Gear5 Segement 7') 
ax1.plot(X6_Gear5['t'], X6_Gear5['fL'], c ='orange')
ax2.set_title('Force Right for Gear5 Segement 7') 
ax2.plot(X6_Gear5['t'], X6_Gear5['fR'], c ='green')
ax1.xaxis.set_ticks(np.arange(0, 40, 1.0))
ax1.yaxis.set_ticks(np.arange(0, 270, 20))
ax2.xaxis.set_ticks(np.arange(0, 40, 1.0))
ax2.yaxis.set_ticks(np.arange(0, 200, 20))
plt.show()
