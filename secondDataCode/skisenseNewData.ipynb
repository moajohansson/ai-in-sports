# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %% [markdown]
# In the cell below all data is uploaded, and labeled.

# %%
gear2 = os.path.normpath('/Users/mariekorneliusson/documents/AiSports/skate_without_video/Gear2/segment4.csv')
gear3 = os.path.normpath('/Users/mariekorneliusson/documents/AiSports/skate_without_video/Gear3/segment2.csv')
gear4 = os.path.normpath('/Users/mariekorneliusson/documents/AiSports/skate_without_video/Gear4/segment4.csv')
dob = os.path.normpath('/Users/mariekorneliusson/documents/AiSports/skate_without_video/Double/segment2.csv')

dataGear2 = pd.read_csv(gear2,low_memory = False)
dataGear3 = pd.read_csv(gear3,low_memory = False)
dataGear4 = pd.read_csv(gear4,low_memory = False)
dataD = pd.read_csv(dob,low_memory = False)
dataD.keys()
# Out:
# Index(['t', 'fL', 'thL', 'w1L', 'w2L', 'w3L', 'a1L', 'a2L', 'a3L', 'fR', 'thR',
#        'w1R', 'w2R', 'w3R', 'a1R', 'a2R', 'a3R', 'x', 'y', 'v', 'vdir'],
#       dtype='object')

# %%
plt.figure(0,figsize=(15, 6))
plt.plot(dataGear2.t,dataGear2.fL,label='Force [N]')
plt.legend()

# %%
dataSkingForceLeftG2 = dataGear2.loc[dataGear2['fL'] >= 1]
dataSkingForceLeftG3 = dataGear3.loc[dataGear3['fL'] >= 1]
dataSkingForceLeftG4 = dataGear4.loc[dataGear4['fL'] >= 2]
dataSkingForceLeftDo = dataD.loc[dataD['fL'] >= 1]

# %%
plt.figure(0)
dataGear2.fL.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force left')
plt.legend()
plt.title('Gear 2 with all data')
plt.figure(1)
dataSkingForceLeftG2.fL.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force left')
plt.legend()
plt.figure(1)
dataSkingForceLeftG2.fR.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force right')
plt.legend()
plt.title('Gear 2')

# %%
plt.figure(0)
dataSkingForceLeftG3.fL.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force left')
plt.legend()
plt.figure(0)
dataSkingForceLeftG3.fR.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force right')
plt.legend()
plt.title('Gear 3')

# %%
plt.figure(0)
dataSkingForceLeftG4.fL.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force left')
plt.legend()
plt.figure(0)
dataSkingForceLeftG4.fR.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force right')
plt.legend()
plt.title('Gear 4')
# Out:
# Text(0.5,1,'Gear 4')

# %%
plt.figure(0)
dataSkingForceLeftDo.fL.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force left')
plt.legend()
plt.figure(0)
dataSkingForceLeftDo.fR.plot(kind='hist', bins=30, alpha=0.7, figsize=[15,6],label = 'Force right')
plt.legend()
plt.title('Double')
