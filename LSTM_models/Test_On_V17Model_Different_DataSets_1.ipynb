# %% [markdown]
# ## Testing on base model V17
#
# #### Train + Val - Initial dataset - skate_without_video
# #### Test - skate_satila

# %%
# import statements

import pandas as pd
import numpy as np
import math
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from pandas import Series

from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, BatchNormalization

from sklearn.model_selection import train_test_split
from random import shuffle

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
# Out:
# /Users/nickeylawrence/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
## Training data

# Read the Gear2 data
Gear2Files = ['./skate_without_video/Gear2/segment2.csv', './skate_without_video/Gear2/segment3.csv','./skate_without_video/Gear2/segment4.csv',
              './skate_without_video/Gear2/segment5.csv','./skate_without_video/Gear2/segment6.csv']

X_Gear2=[0] * len(Gear2Files)
Y_Gear2=[0] * len(Gear2Files)
for index,file in enumerate(Gear2Files):
    X_Gear2[index] = pd.read_csv(file);
    Y_Gear2[index] = pd.DataFrame(data= np.full((X_Gear2[index].shape[0],1), 2));
    X_Gear2[index] = X_Gear2[index].assign(Gear=Y_Gear2[index].values);

# Read the Gear3 data
Gear3Files = ['./skate_without_video/Gear3/segment1.csv', './skate_without_video/Gear3/segment2.csv','./skate_without_video/Gear3/segment3.csv',
              './skate_without_video/Gear3/segment4.csv','./skate_without_video/Gear3/segment5.csv', './skate_without_video/Gear3/segment6.csv']

X_Gear3=[0] * len(Gear3Files)
Y_Gear3=[0] * len(Gear3Files)
for index,file in enumerate(Gear3Files):
    X_Gear3[index] = pd.read_csv(file);
    Y_Gear3[index] = pd.DataFrame(data= np.full((X_Gear3[index].shape[0],1), 3));
    X_Gear3[index] = X_Gear3[index].assign(Gear=Y_Gear3[index].values);

# Read the Gear4 data
Gear4Files = ['./skate_without_video/Gear4/segment2.csv','./skate_without_video/Gear4/segment3.csv','./skate_without_video/Gear4/segment4.csv',
              './skate_without_video/Gear4/segment5.csv', './skate_without_video/Gear4/segment6a.csv','./skate_without_video/Gear4/segment6b.csv']

X_Gear4=[0] * len(Gear4Files)
Y_Gear4=[0] * len(Gear4Files)
for index,file in enumerate(Gear4Files):
    X_Gear4[index] = pd.read_csv(file);
    Y_Gear4[index] = pd.DataFrame(data= np.full((X_Gear4[index].shape[0],1), 4));
    X_Gear4[index] = X_Gear4[index].assign(Gear=Y_Gear4[index].values);

# Read the Gear 5 data
Gear5Files = ['./skate_without_video/Double/segment1.csv','./skate_without_video/Double/segment2.csv','./skate_without_video/Double/segment3.csv',
              './skate_without_video/Double/segment4.csv', './skate_without_video/Double/segment5.csv','./skate_without_video/Double/segment7.csv']

X_Gear5=[0] * len(Gear5Files)
Y_Gear5=[0] * len(Gear5Files)
for index,file in enumerate(Gear5Files):
    X_Gear5[index] = pd.read_csv(file);
    Y_Gear5[index] = pd.DataFrame(data= np.full((X_Gear5[index].shape[0],1), 5));
    X_Gear5[index] = X_Gear5[index].assign(Gear=Y_Gear5[index].values);

# %%
# Implement moving average for a window size of 3, and split the segments such that each has 750 time-steps, 
# for training data

limit = 750
features = list(X_Gear2[0].columns);
scaledFeatures = [item for item in features if item not in ['t','Gear']]

XGear=[]
for index in range(len(X_Gear2)):
    dataG2 = X_Gear2[index];
    x = dataG2[scaledFeatures];
    rolling = x.rolling(window=10);
    rolling_mean = rolling.mean();
    X_Gear2[index][scaledFeatures] = rolling_mean;
    dataG2 = X_Gear2[index].iloc[10:, :];
    gearRange = math.ceil(len(dataG2)/limit);
    XGear += [dataG2[t*limit:t*limit + limit] for t in range(gearRange)];  
    
for index in range(len(X_Gear3)):
    dataG3 = X_Gear3[index];
    x = dataG3[scaledFeatures];
    rolling = x.rolling(window=10);
    rolling_mean = rolling.mean();
    X_Gear3[index][scaledFeatures] = rolling_mean;
    dataG3 = X_Gear3[index].iloc[10:, :];
    gearRange = math.ceil(len(dataG3)/limit);
    XGear += [dataG3[t*limit:t*limit + limit] for t in range(gearRange)];  
    
for index in range(len(X_Gear4)):
    dataG4 = X_Gear4[index];
    x = dataG4[scaledFeatures];
    rolling = x.rolling(window=10);
    rolling_mean = rolling.mean();
    X_Gear4[index][scaledFeatures] = rolling_mean;
    dataG4 = X_Gear4[index].iloc[10:, :];
    gearRange = math.ceil(len(dataG4)/limit);
    XGear += [dataG4[t*limit:t*limit + limit] for t in range(gearRange)];  
    
    
for index in range(len(X_Gear5)):
    dataG5 = X_Gear5[index];
    x = dataG5[scaledFeatures];
    rolling = x.rolling(window=10);
    rolling_mean = rolling.mean();
    X_Gear5[index][scaledFeatures] = rolling_mean;
    dataG5 = X_Gear5[index].iloc[10:, :];
    gearRange = math.ceil(len(dataG5)/limit);
    XGear += [dataG5[t*limit:t*limit + limit] for t in range(gearRange)];

# %%
## Test data

testGear2Files = ['./skate_satila/Gear2_1.csv', './skate_satila/Gear2_2.csv']
testGear3Files = ['./skate_satila/Gear3_1.csv', './skate_satila/Gear3_2.csv']
testGear4Files = ['./skate_satila/Gear4_1.csv']
testDoubleFiles = ['./skate_satila/Double_1.csv', './skate_satila/Double_2.csv', './skate_satila/Double_3.csv']

# Read the Gear 2 data
testX_Gear2=[0] * len(testGear2Files)
testY_Gear2=[0] * len(testGear2Files)
for index,file in enumerate(testGear2Files):
    testX_Gear2[index] = pd.read_csv(file);
    testY_Gear2[index] = pd.DataFrame(data= np.full((testX_Gear2[index].shape[0],1), 2));
    testX_Gear2[index] = testX_Gear2[index].assign(Gear=testY_Gear2[index].values);


# Read the Gear 3 data
testX_Gear3=[0] * len(testGear3Files)
testY_Gear3=[0] * len(testGear3Files)
for index,file in enumerate(testGear3Files):
    testX_Gear3[index] = pd.read_csv(file);
    testY_Gear3[index] = pd.DataFrame(data= np.full((testX_Gear3[index].shape[0],1), 3));
    testX_Gear3[index] = testX_Gear3[index].assign(Gear=testY_Gear3[index].values);


# Read the Gear 4 data
testX_Gear4=[0] * len(testGear4Files)
testY_Gear4=[0] * len(testGear4Files)
for index,file in enumerate(testGear4Files):
    testX_Gear4[index] = pd.read_csv(file);
    testY_Gear4[index] = pd.DataFrame(data= np.full((testX_Gear4[index].shape[0],1), 4));
    testX_Gear4[index] = testX_Gear4[index].assign(Gear=testY_Gear4[index].values);


# Read the Gear Double data
testX_GearD=[0] * len(testDoubleFiles)
testY_GearD=[0] * len(testDoubleFiles)
for index,file in enumerate(testDoubleFiles):
    testX_GearD[index] = pd.read_csv(file);
    testY_GearD[index] = pd.DataFrame(data= np.full((testX_GearD[index].shape[0],1), 5));
    testX_GearD[index] = testX_GearD[index].assign(Gear=testY_GearD[index].values);


limit = 750

testXGear=[]
for index, dataG2 in enumerate(testX_Gear2):
    gearRange = math.ceil(len(dataG2)/limit)
    testXGear += [dataG2[t*limit:t*limit + limit] for t in range(gearRange)]

for index, dataG3 in enumerate(testX_Gear3):
    gearRange = math.ceil(len(dataG3)/limit)
    testXGear += [dataG3[t*limit:t*limit + limit] for t in range(gearRange)]

for index, dataG4 in enumerate(testX_Gear4):
    gearRange = math.ceil(len(dataG4)/limit)
    testXGear += [dataG4[t*limit:t*limit + limit] for t in range(gearRange)]
    
for index, dataGD in enumerate(testX_GearD):
    gearRange = math.ceil(len(dataGD)/limit)
    testXGear += [dataGD[t*limit:t*limit + limit] for t in range(gearRange)]

# %%
# training data
X = XGear[:] # Copy words
shuffle(X) 

X = pd.concat(X);

data = pd.DataFrame(X);

data.reset_index(inplace = True, drop = True)
for i in range(len(data)):
    data.loc[i,'t'] = i*0.02

# %%
# test data
testX = testXGear[:] 
testX = pd.concat(testX);

testData = pd.DataFrame(testX);

testData.reset_index(inplace = True, drop = True)
for i in range(len(testData)):
    testData.loc[i,'t'] = i*0.02

# %%
# Normalisation
# Feature normalization
# Normalize Time Series Data
# Source : https://machinelearningmastery.com/normalize-standardize-time-series-data-python/

# Normalization is a rescaling of the data from the original range so that all values are within the range of 0 and 1.
# useful when your time series data has input values with differing scales.

# Normalize training data
features = list(data.columns);
scaledFeatures = [item for item in features if item not in ['t','Gear']]

for i in range(len(scaledFeatures)):
    feature = scaledFeatures[i];
    print('Scaling feature : ', scaledFeatures[i])
    values1 = X[feature].values.reshape(-1,1);
    values1 = values1.astype('float32');
    scaler = MinMaxScaler(feature_range = (0,1));
    scaled_f = scaler.fit_transform(values1);
    X[feature] = scaled_f;
    
    
# Normalize test data 
testfeatures = list(testData.columns);
scaledTestFeatures = [item for item in testfeatures if item not in ['t','Gear']]

for i in range(len(scaledTestFeatures)):
    feature = scaledTestFeatures[i];
    print('Scaling feature : ', scaledTestFeatures[i])
    values2 = testX[feature].values.reshape(-1,1);
    values2 = values2.astype('float32');
    scaler = MinMaxScaler(feature_range = (0,1));
    scaled_f = scaler.fit_transform(values2);
    testX[feature] = scaled_f;
# Out:
# Scaling feature :  fL
# Scaling feature :  thL
# Scaling feature :  w1L
# Scaling feature :  w2L
# Scaling feature :  w3L
# Scaling feature :  a1L
# Scaling feature :  a2L
# Scaling feature :  a3L
# Scaling feature :  fR
# Scaling feature :  thR
# Scaling feature :  w1R
# Scaling feature :  w2R
# Scaling feature :  w3R
# Scaling feature :  a1R
# Scaling feature :  a2R
# Scaling feature :  a3R
# Scaling feature :  x
# Scaling feature :  y
# Scaling feature :  v
# Scaling feature :  vdir
# Scaling feature :  fL
# Scaling feature :  thL
# Scaling feature :  w1L
# Scaling feature :  w2L
# Scaling feature :  w3L
# Scaling feature :  a1L
# Scaling feature :  a2L
# Scaling feature :  a3L
# Scaling feature :  fR
# Scaling feature :  thR
# Scaling feature :  w1R
# Scaling feature :  w2R
# Scaling feature :  w3R
# Scaling feature :  a1R
# Scaling feature :  a2R
# Scaling feature :  a3R
# Scaling feature :  x
# Scaling feature :  y
# Scaling feature :  z
# Scaling feature :  v

# %%
# Create one-hot Y vectors
features.remove('Gear')
features.remove('x')
features.remove('y')
features.remove('v')

X = data[features]
Y = data['Gear']

# %%
testfeatures.remove('Gear')
testfeatures.remove('x')
testfeatures.remove('y')
testfeatures.remove('z')

testX = testData[testfeatures]
testY = testData['Gear']

# %%
# Create one-hot Y vectors
Y_onehot = pd.get_dummies(Y).values;
testY_onehot = pd.get_dummies(testY).values;

# %%
X = np.array(X)
Y = np.array(Y_onehot)

testX = np.array(testX)
testY = np.array(testY_onehot)

# %%
# Create training, validation data and test data
timesteps = 1
XNew = X.reshape(X.shape[0],timesteps,18)
YNew = Y.reshape(Y.shape[0],timesteps,4)

# trainX, testX, trainY, testY = train_test_split(XNew, YNew, test_size=0.2);
# trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.2);

trainX, valX, trainY, valY = train_test_split(XNew, YNew, test_size=0.2);
testX = testX.reshape(testX.shape[0],timesteps,18)
testY = testY.reshape(testY.shape[0],timesteps,4)

# %%
# design and fit our LSTM network

model = Sequential();
model.add(LSTM(64, return_sequences = True, input_shape = (timesteps, 17)));
model.add(Dense(4, activation = 'softmax'));
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
history = model.fit(trainX[:,:,1:], trainY, epochs=200, batch_size=100, validation_data=(valX[:,:,1:],valY))
# Out:
# Train on 20576 samples, validate on 5144 samples
# Epoch 1/200
# 20576/20576 [==============================] - 8s 402us/step - loss: 1.3014 - categorical_accuracy: 0.4030 - val_loss: 1.1856 - val_categorical_accuracy: 0.4650
# Epoch 2/200
# 20576/20576 [==============================] - 7s 335us/step - loss: 1.1029 - categorical_accuracy: 0.4890 - val_loss: 1.0629 - val_categorical_accuracy: 0.4914
# Epoch 3/200
# 20576/20576 [==============================] - 9s 428us/step - loss: 1.0310 - categorical_accuracy: 0.5182 - val_loss: 1.0209 - val_categorical_accuracy: 0.5391
# Epoch 4/200
# 20576/20576 [==============================] - 10s 492us/step - loss: 1.0003 - categorical_accuracy: 0.5405 - val_loss: 0.9943 - val_categorical_accuracy: 0.5533
# Epoch 5/200
# 20576/20576 [==============================] - 11s 517us/step - loss: 0.9757 - categorical_accuracy: 0.5590 - val_loss: 0.9773 - val_categorical_accuracy: 0.5430
# Epoch 6/200
# 20576/20576 [==============================] - 9s 444us/step - loss: 0.9575 - categorical_accuracy: 0.5720 - val_loss: 0.9561 - val_categorical_accuracy: 0.5770
# Epoch 7/200
# 20576/20576 [==============================] - 9s 449us/step - loss: 0.9371 - categorical_accuracy: 0.5902 - val_loss: 0.9314 - val_categorical_accuracy: 0.5984
# Epoch 8/200
# 20576/20576 [==============================] - 9s 455us/step - loss: 0.9190 - categorical_accuracy: 0.6033 - val_loss: 0.9148 - val_categorical_accuracy: 0.6083
# Epoch 9/200
# 20576/20576 [==============================] - 9s 450us/step - loss: 0.8991 - categorical_accuracy: 0.6206 - val_loss: 0.9066 - val_categorical_accuracy: 0.6174
# Epoch 10/200
# 20576/20576 [==============================] - 9s 446us/step - loss: 0.8758 - categorical_accuracy: 0.6362 - val_loss: 0.8669 - val_categorical_accuracy: 0.6544
# Epoch 11/200
# 20576/20576 [==============================] - 9s 446us/step - loss: 0.8538 - categorical_accuracy: 0.6512 - val_loss: 0.8460 - val_categorical_accuracy: 0.6493
# Epoch 12/200
# 20576/20576 [==============================] - 9s 454us/step - loss: 0.8288 - categorical_accuracy: 0.6648 - val_loss: 0.8207 - val_categorical_accuracy: 0.6697
# Epoch 13/200
# 20576/20576 [==============================] - 9s 445us/step - loss: 0.8058 - categorical_accuracy: 0.6763 - val_loss: 0.7999 - val_categorical_accuracy: 0.6878
# Epoch 14/200
# 20576/20576 [==============================] - 9s 445us/step - loss: 0.7837 - categorical_accuracy: 0.6886 - val_loss: 0.7762 - val_categorical_accuracy: 0.6820
# Epoch 15/200
# 20576/20576 [==============================] - 9s 456us/step - loss: 0.7617 - categorical_accuracy: 0.6999 - val_loss: 0.7643 - val_categorical_accuracy: 0.6991
# Epoch 16/200
# 20576/20576 [==============================] - 9s 449us/step - loss: 0.7416 - categorical_accuracy: 0.7080 - val_loss: 0.7391 - val_categorical_accuracy: 0.7014
# Epoch 17/200
# 20576/20576 [==============================] - 9s 441us/step - loss: 0.7260 - categorical_accuracy: 0.7143 - val_loss: 0.7218 - val_categorical_accuracy: 0.7066
# Epoch 18/200
# 20576/20576 [==============================] - 9s 450us/step - loss: 0.7082 - categorical_accuracy: 0.7226 - val_loss: 0.7032 - val_categorical_accuracy: 0.7249
# Epoch 19/200
# 20576/20576 [==============================] - 9s 452us/step - loss: 0.6909 - categorical_accuracy: 0.7346 - val_loss: 0.6941 - val_categorical_accuracy: 0.7302
# Epoch 20/200
# 20576/20576 [==============================] - 9s 446us/step - loss: 0.6783 - categorical_accuracy: 0.7355 - val_loss: 0.6744 - val_categorical_accuracy: 0.7407
# Epoch 21/200
# 20576/20576 [==============================] - 9s 458us/step - loss: 0.6629 - categorical_accuracy: 0.7447 - val_loss: 0.6640 - val_categorical_accuracy: 0.7368
# Epoch 22/200
# 20576/20576 [==============================] - 10s 473us/step - loss: 0.6510 - categorical_accuracy: 0.7508 - val_loss: 0.6583 - val_categorical_accuracy: 0.7385
# Epoch 23/200
# 20576/20576 [==============================] - 9s 446us/step - loss: 0.6402 - categorical_accuracy: 0.7522 - val_loss: 0.6455 - val_categorical_accuracy: 0.7566
# Epoch 24/200
# 20576/20576 [==============================] - 9s 455us/step - loss: 0.6291 - categorical_accuracy: 0.7576 - val_loss: 0.6384 - val_categorical_accuracy: 0.7461
# Epoch 25/200
# 20576/20576 [==============================] - 9s 459us/step - loss: 0.6184 - categorical_accuracy: 0.7632 - val_loss: 0.6286 - val_categorical_accuracy: 0.7451
# Epoch 26/200
# 20576/20576 [==============================] - 9s 461us/step - loss: 0.6090 - categorical_accuracy: 0.7665 - val_loss: 0.6165 - val_categorical_accuracy: 0.7589
# Epoch 27/200
# 20576/20576 [==============================] - 9s 458us/step - loss: 0.5996 - categorical_accuracy: 0.7693 - val_loss: 0.6042 - val_categorical_accuracy: 0.7702 - loss: 0.5
# Epoch 28/200
# 20576/20576 [==============================] - 9s 459us/step - loss: 0.5918 - categorical_accuracy: 0.7739 - val_loss: 0.5968 - val_categorical_accuracy: 0.7747
# Epoch 29/200
# 20576/20576 [==============================] - 9s 453us/step - loss: 0.5810 - categorical_accuracy: 0.7802 - val_loss: 0.5875 - val_categorical_accuracy: 0.7720
# Epoch 30/200
# 20576/20576 [==============================] - 9s 457us/step - loss: 0.5739 - categorical_accuracy: 0.7812 - val_loss: 0.5776 - val_categorical_accuracy: 0.7813
# Epoch 31/200
# 20576/20576 [==============================] - 9s 460us/step - loss: 0.5663 - categorical_accuracy: 0.7859 - val_loss: 0.5717 - val_categorical_accuracy: 0.7809
# Epoch 32/200
# 20576/20576 [==============================] - 9s 454us/step - loss: 0.5573 - categorical_accuracy: 0.7901 - val_loss: 0.5707 - val_categorical_accuracy: 0.7803
# Epoch 33/200
# 20576/20576 [==============================] - 9s 454us/step - loss: 0.5506 - categorical_accuracy: 0.7925 - val_loss: 0.5581 - val_categorical_accuracy: 0.7883
# Epoch 34/200
# 20576/20576 [==============================] - 10s 470us/step - loss: 0.5451 - categorical_accuracy: 0.7927 - val_loss: 0.5542 - val_categorical_accuracy: 0.7864
# Epoch 35/200
# 20576/20576 [==============================] - 9s 448us/step - loss: 0.5380 - categorical_accuracy: 0.7977 - val_loss: 0.5474 - val_categorical_accuracy: 0.7922
# Epoch 36/200
# 20576/20576 [==============================] - 10s 510us/step - loss: 0.5310 - categorical_accuracy: 0.8006 - val_loss: 0.5400 - val_categorical_accuracy: 0.7941
# Epoch 37/200
# 20576/20576 [==============================] - 11s 513us/step - loss: 0.5237 - categorical_accuracy: 0.8028 - val_loss: 0.5391 - val_categorical_accuracy: 0.7970
# Epoch 38/200
# 20576/20576 [==============================] - 10s 488us/step - loss: 0.5210 - categorical_accuracy: 0.8033 - val_loss: 0.5294 - val_categorical_accuracy: 0.7969
# Epoch 39/200
# 20576/20576 [==============================] - 12s 560us/step - loss: 0.5128 - categorical_accuracy: 0.8088 - val_loss: 0.5238 - val_categorical_accuracy: 0.8013
# Epoch 40/200
# 20576/20576 [==============================] - 9s 425us/step - loss: 0.5084 - categorical_accuracy: 0.8072 - val_loss: 0.5174 - val_categorical_accuracy: 0.8000
# Epoch 41/200
# 20576/20576 [==============================] - 11s 522us/step - loss: 0.5012 - categorical_accuracy: 0.8124 - val_loss: 0.5140 - val_categorical_accuracy: 0.8068
# Epoch 42/200
# 20576/20576 [==============================] - 12s 565us/step - loss: 0.4958 - categorical_accuracy: 0.8163 - val_loss: 0.5059 - val_categorical_accuracy: 0.8099
# Epoch 43/200
# 20576/20576 [==============================] - 11s 520us/step - loss: 0.4903 - categorical_accuracy: 0.8174 - val_loss: 0.4973 - val_categorical_accuracy: 0.8112
# Epoch 44/200
# 20576/20576 [==============================] - 10s 502us/step - loss: 0.4840 - categorical_accuracy: 0.8199 - val_loss: 0.4918 - val_categorical_accuracy: 0.8140
# Epoch 45/200
# 20576/20576 [==============================] - 12s 567us/step - loss: 0.4804 - categorical_accuracy: 0.8218 - val_loss: 0.4865 - val_categorical_accuracy: 0.8163
# Epoch 46/200
# 20576/20576 [==============================] - 13s 625us/step - loss: 0.4739 - categorical_accuracy: 0.8228 - val_loss: 0.4828 - val_categorical_accuracy: 0.8196
# Epoch 47/200
# 20576/20576 [==============================] - 12s 562us/step - loss: 0.4703 - categorical_accuracy: 0.8249 - val_loss: 0.4808 - val_categorical_accuracy: 0.8155
# Epoch 48/200
# 20576/20576 [==============================] - 11s 555us/step - loss: 0.4677 - categorical_accuracy: 0.8264 - val_loss: 0.4793 - val_categorical_accuracy: 0.8225
# Epoch 49/200
# 20576/20576 [==============================] - 11s 549us/step - loss: 0.4604 - categorical_accuracy: 0.8303 - val_loss: 0.4673 - val_categorical_accuracy: 0.8268
# Epoch 50/200
# 20576/20576 [==============================] - 11s 546us/step - loss: 0.4577 - categorical_accuracy: 0.8295 - val_loss: 0.4675 - val_categorical_accuracy: 0.8237
# Epoch 51/200
# 20576/20576 [==============================] - 12s 565us/step - loss: 0.4529 - categorical_accuracy: 0.8342 - val_loss: 0.4650 - val_categorical_accuracy: 0.8305
# Epoch 52/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.4496 - categorical_accuracy: 0.8331 - val_loss: 0.4570 - val_categorical_accuracy: 0.8285
# Epoch 53/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.4435 - categorical_accuracy: 0.8365 - val_loss: 0.4511 - val_categorical_accuracy: 0.8326
# Epoch 54/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.4405 - categorical_accuracy: 0.8385 - val_loss: 0.4496 - val_categorical_accuracy: 0.8303
# Epoch 55/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.4358 - categorical_accuracy: 0.8394 - val_loss: 0.4498 - val_categorical_accuracy: 0.8309
# Epoch 56/200
# 20576/20576 [==============================] - 11s 548us/step - loss: 0.4315 - categorical_accuracy: 0.8412 - val_loss: 0.4407 - val_categorical_accuracy: 0.8316
# Epoch 57/200
# 20576/20576 [==============================] - 11s 533us/step - loss: 0.4286 - categorical_accuracy: 0.8426 - val_loss: 0.4430 - val_categorical_accuracy: 0.8336
# Epoch 58/200
# 20576/20576 [==============================] - 11s 534us/step - loss: 0.4249 - categorical_accuracy: 0.8436 - val_loss: 0.4397 - val_categorical_accuracy: 0.8400
# Epoch 59/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.4217 - categorical_accuracy: 0.8458 - val_loss: 0.4308 - val_categorical_accuracy: 0.8462
# Epoch 60/200
# 20576/20576 [==============================] - 11s 547us/step - loss: 0.4166 - categorical_accuracy: 0.8482 - val_loss: 0.4251 - val_categorical_accuracy: 0.8458
# Epoch 61/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.4130 - categorical_accuracy: 0.8509 - val_loss: 0.4221 - val_categorical_accuracy: 0.8490
# Epoch 62/200
# 20576/20576 [==============================] - 11s 544us/step - loss: 0.4085 - categorical_accuracy: 0.8518 - val_loss: 0.4167 - val_categorical_accuracy: 0.8521
# Epoch 63/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.4076 - categorical_accuracy: 0.8520 - val_loss: 0.4150 - val_categorical_accuracy: 0.8478
# Epoch 64/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.4042 - categorical_accuracy: 0.8527 - val_loss: 0.4150 - val_categorical_accuracy: 0.8449
# Epoch 65/200
# 20576/20576 [==============================] - 11s 539us/step - loss: 0.3990 - categorical_accuracy: 0.8569 - val_loss: 0.4082 - val_categorical_accuracy: 0.8491
# Epoch 66/200
# 20576/20576 [==============================] - 12s 603us/step - loss: 0.3979 - categorical_accuracy: 0.8536 - val_loss: 0.4051 - val_categorical_accuracy: 0.8528
# Epoch 67/200
# 20576/20576 [==============================] - 13s 654us/step - loss: 0.3932 - categorical_accuracy: 0.8579 - val_loss: 0.3999 - val_categorical_accuracy: 0.8565
# Epoch 68/200
# 20576/20576 [==============================] - 11s 516us/step - loss: 0.3918 - categorical_accuracy: 0.8571 - val_loss: 0.4003 - val_categorical_accuracy: 0.8524
# Epoch 69/200
# 20576/20576 [==============================] - 11s 535us/step - loss: 0.3874 - categorical_accuracy: 0.8599 - val_loss: 0.3925 - val_categorical_accuracy: 0.8563
# Epoch 70/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.3856 - categorical_accuracy: 0.8597 - val_loss: 0.3959 - val_categorical_accuracy: 0.8513
# Epoch 71/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.3811 - categorical_accuracy: 0.8598 - val_loss: 0.3890 - val_categorical_accuracy: 0.8604
# Epoch 72/200
# 20576/20576 [==============================] - 11s 547us/step - loss: 0.3789 - categorical_accuracy: 0.8630 - val_loss: 0.3844 - val_categorical_accuracy: 0.8624
# Epoch 73/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.3746 - categorical_accuracy: 0.8645 - val_loss: 0.3941 - val_categorical_accuracy: 0.8528
# Epoch 74/200
# 20576/20576 [==============================] - 11s 535us/step - loss: 0.3738 - categorical_accuracy: 0.8634 - val_loss: 0.3810 - val_categorical_accuracy: 0.8589
# Epoch 75/200
# 20576/20576 [==============================] - 11s 546us/step - loss: 0.3684 - categorical_accuracy: 0.8667 - val_loss: 0.3788 - val_categorical_accuracy: 0.8612
# Epoch 76/200
# 20576/20576 [==============================] - 11s 533us/step - loss: 0.3665 - categorical_accuracy: 0.8669 - val_loss: 0.3805 - val_categorical_accuracy: 0.8598
# Epoch 77/200
# 20576/20576 [==============================] - 11s 553us/step - loss: 0.3652 - categorical_accuracy: 0.8696 - val_loss: 0.3716 - val_categorical_accuracy: 0.8655
# Epoch 78/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.3626 - categorical_accuracy: 0.8688 - val_loss: 0.3697 - val_categorical_accuracy: 0.8668
# Epoch 79/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.3600 - categorical_accuracy: 0.8694 - val_loss: 0.3725 - val_categorical_accuracy: 0.8672
# Epoch 80/200
# 20576/20576 [==============================] - 11s 543us/step - loss: 0.3561 - categorical_accuracy: 0.8697 - val_loss: 0.3669 - val_categorical_accuracy: 0.8664
# Epoch 81/200
# 20576/20576 [==============================] - 11s 547us/step - loss: 0.3544 - categorical_accuracy: 0.8705 - val_loss: 0.3665 - val_categorical_accuracy: 0.8635
# Epoch 82/200
# 20576/20576 [==============================] - 11s 531us/step - loss: 0.3518 - categorical_accuracy: 0.8722 - val_loss: 0.3612 - val_categorical_accuracy: 0.8696
# Epoch 83/200
# 20576/20576 [==============================] - 11s 534us/step - loss: 0.3497 - categorical_accuracy: 0.8735 - val_loss: 0.3558 - val_categorical_accuracy: 0.8670
# Epoch 84/200
# 20576/20576 [==============================] - 11s 538us/step - loss: 0.3467 - categorical_accuracy: 0.8739 - val_loss: 0.3598 - val_categorical_accuracy: 0.8719
# Epoch 85/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.3455 - categorical_accuracy: 0.8760 - val_loss: 0.3519 - val_categorical_accuracy: 0.8734
# Epoch 86/200
# 20576/20576 [==============================] - 11s 544us/step - loss: 0.3427 - categorical_accuracy: 0.8760 - val_loss: 0.3559 - val_categorical_accuracy: 0.8746ss: 0.3426 - cate
# Epoch 87/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.3416 - categorical_accuracy: 0.8740 - val_loss: 0.3482 - val_categorical_accuracy: 0.8701
# Epoch 88/200
# 20576/20576 [==============================] - 14s 681us/step - loss: 0.3381 - categorical_accuracy: 0.8780 - val_loss: 0.3465 - val_categorical_accuracy: 0.8738
# Epoch 89/200
# 20576/20576 [==============================] - 12s 603us/step - loss: 0.3359 - categorical_accuracy: 0.8792 - val_loss: 0.3494 - val_categorical_accuracy: 0.8690
# Epoch 90/200
# 20576/20576 [==============================] - 12s 602us/step - loss: 0.3338 - categorical_accuracy: 0.8793 - val_loss: 0.3428 - val_categorical_accuracy: 0.8721
# Epoch 91/200
# 20576/20576 [==============================] - 11s 558us/step - loss: 0.3322 - categorical_accuracy: 0.8802 - val_loss: 0.3413 - val_categorical_accuracy: 0.8719
# Epoch 92/200
# 20576/20576 [==============================] - 12s 566us/step - loss: 0.3288 - categorical_accuracy: 0.8818 - val_loss: 0.3410 - val_categorical_accuracy: 0.8779
# Epoch 93/200
# 20576/20576 [==============================] - 12s 572us/step - loss: 0.3280 - categorical_accuracy: 0.8804 - val_loss: 0.3364 - val_categorical_accuracy: 0.8771
# Epoch 94/200
# 20576/20576 [==============================] - 12s 562us/step - loss: 0.3240 - categorical_accuracy: 0.8816 - val_loss: 0.3357 - val_categorical_accuracy: 0.8773
# Epoch 95/200
# 20576/20576 [==============================] - 11s 520us/step - loss: 0.3238 - categorical_accuracy: 0.8833 - val_loss: 0.3301 - val_categorical_accuracy: 0.8806
# Epoch 96/200
# 20576/20576 [==============================] - 11s 551us/step - loss: 0.3209 - categorical_accuracy: 0.8850 - val_loss: 0.3315 - val_categorical_accuracy: 0.8806
# Epoch 97/200
# 20576/20576 [==============================] - 11s 534us/step - loss: 0.3211 - categorical_accuracy: 0.8833 - val_loss: 0.3258 - val_categorical_accuracy: 0.8830
# Epoch 98/200
# 20576/20576 [==============================] - 11s 552us/step - loss: 0.3166 - categorical_accuracy: 0.8857 - val_loss: 0.3279 - val_categorical_accuracy: 0.8797
# Epoch 99/200
# 20576/20576 [==============================] - 11s 537us/step - loss: 0.3171 - categorical_accuracy: 0.8857 - val_loss: 0.3254 - val_categorical_accuracy: 0.8808
# Epoch 100/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.3129 - categorical_accuracy: 0.8879 - val_loss: 0.3241 - val_categorical_accuracy: 0.8808
# Epoch 101/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.3120 - categorical_accuracy: 0.8855 - val_loss: 0.3187 - val_categorical_accuracy: 0.8806
# Epoch 102/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.3100 - categorical_accuracy: 0.8878 - val_loss: 0.3182 - val_categorical_accuracy: 0.8853
# Epoch 103/200
# 20576/20576 [==============================] - 11s 539us/step - loss: 0.3083 - categorical_accuracy: 0.8882 - val_loss: 0.3220 - val_categorical_accuracy: 0.8816
# Epoch 104/200
# 20576/20576 [==============================] - 12s 566us/step - loss: 0.3068 - categorical_accuracy: 0.8892 - val_loss: 0.3160 - val_categorical_accuracy: 0.8851
# Epoch 105/200
# 20576/20576 [==============================] - 11s 533us/step - loss: 0.3041 - categorical_accuracy: 0.8905 - val_loss: 0.3158 - val_categorical_accuracy: 0.8837
# Epoch 106/200
# 20576/20576 [==============================] - 11s 543us/step - loss: 0.3030 - categorical_accuracy: 0.8893 - val_loss: 0.3103 - val_categorical_accuracy: 0.8861
# Epoch 107/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.3015 - categorical_accuracy: 0.8908 - val_loss: 0.3153 - val_categorical_accuracy: 0.8834
# Epoch 108/200
# 20576/20576 [==============================] - 11s 538us/step - loss: 0.3026 - categorical_accuracy: 0.8888 - val_loss: 0.3112 - val_categorical_accuracy: 0.8880
# Epoch 109/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.2998 - categorical_accuracy: 0.8912 - val_loss: 0.3061 - val_categorical_accuracy: 0.8871
# Epoch 110/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.2954 - categorical_accuracy: 0.8934 - val_loss: 0.3053 - val_categorical_accuracy: 0.8892
# Epoch 111/200
# 20576/20576 [==============================] - 11s 527us/step - loss: 0.2943 - categorical_accuracy: 0.8936 - val_loss: 0.3052 - val_categorical_accuracy: 0.8878
# Epoch 112/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.2963 - categorical_accuracy: 0.8906 - val_loss: 0.3011 - val_categorical_accuracy: 0.8898
# Epoch 113/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.2929 - categorical_accuracy: 0.8928 - val_loss: 0.2999 - val_categorical_accuracy: 0.8896
# Epoch 114/200
# 20576/20576 [==============================] - 11s 543us/step - loss: 0.2896 - categorical_accuracy: 0.8935 - val_loss: 0.2983 - val_categorical_accuracy: 0.8898
# Epoch 115/200
# 20576/20576 [==============================] - 12s 564us/step - loss: 0.2892 - categorical_accuracy: 0.8950 - val_loss: 0.2999 - val_categorical_accuracy: 0.8900
# Epoch 116/200
# 20576/20576 [==============================] - 11s 537us/step - loss: 0.2878 - categorical_accuracy: 0.8961 - val_loss: 0.2956 - val_categorical_accuracy: 0.8937
# Epoch 117/200
# 20576/20576 [==============================] - 13s 650us/step - loss: 0.2855 - categorical_accuracy: 0.8965 - val_loss: 0.2995 - val_categorical_accuracy: 0.8863
# Epoch 118/200
# 20576/20576 [==============================] - 13s 639us/step - loss: 0.2847 - categorical_accuracy: 0.8969 - val_loss: 0.2954 - val_categorical_accuracy: 0.8904
# Epoch 119/200
# 20576/20576 [==============================] - 11s 539us/step - loss: 0.2838 - categorical_accuracy: 0.8964 - val_loss: 0.2997 - val_categorical_accuracy: 0.8847
# Epoch 120/200
# 20576/20576 [==============================] - 11s 545us/step - loss: 0.2818 - categorical_accuracy: 0.8968 - val_loss: 0.2994 - val_categorical_accuracy: 0.8927
# Epoch 121/200
# 20576/20576 [==============================] - 11s 531us/step - loss: 0.2795 - categorical_accuracy: 0.8982 - val_loss: 0.2908 - val_categorical_accuracy: 0.8919
# Epoch 122/200
# 20576/20576 [==============================] - 11s 526us/step - loss: 0.2794 - categorical_accuracy: 0.8971 - val_loss: 0.2864 - val_categorical_accuracy: 0.8952
# Epoch 123/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.2772 - categorical_accuracy: 0.8985 - val_loss: 0.2875 - val_categorical_accuracy: 0.8939
# Epoch 124/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.2772 - categorical_accuracy: 0.8993 - val_loss: 0.2833 - val_categorical_accuracy: 0.8954
# Epoch 125/200
# 20576/20576 [==============================] - 11s 550us/step - loss: 0.2747 - categorical_accuracy: 0.8995 - val_loss: 0.2929 - val_categorical_accuracy: 0.8872
# Epoch 126/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.2736 - categorical_accuracy: 0.9001 - val_loss: 0.2847 - val_categorical_accuracy: 0.8923
# Epoch 127/200
# 20576/20576 [==============================] - 11s 533us/step - loss: 0.2731 - categorical_accuracy: 0.8996 - val_loss: 0.2956 - val_categorical_accuracy: 0.8894
# Epoch 128/200
# 20576/20576 [==============================] - 11s 547us/step - loss: 0.2712 - categorical_accuracy: 0.9012 - val_loss: 0.2835 - val_categorical_accuracy: 0.8942
# Epoch 129/200
# 20576/20576 [==============================] - 11s 531us/step - loss: 0.2699 - categorical_accuracy: 0.9021 - val_loss: 0.2831 - val_categorical_accuracy: 0.8929
# Epoch 130/200
# 20576/20576 [==============================] - 11s 544us/step - loss: 0.2679 - categorical_accuracy: 0.9028 - val_loss: 0.2848 - val_categorical_accuracy: 0.8927
# Epoch 131/200
# 20576/20576 [==============================] - 12s 574us/step - loss: 0.2680 - categorical_accuracy: 0.9013 - val_loss: 0.2754 - val_categorical_accuracy: 0.8968
# Epoch 132/200
# 20576/20576 [==============================] - 12s 599us/step - loss: 0.2661 - categorical_accuracy: 0.9036 - val_loss: 0.2758 - val_categorical_accuracy: 0.8976
# Epoch 133/200
# 20576/20576 [==============================] - 12s 596us/step - loss: 0.2646 - categorical_accuracy: 0.9029 - val_loss: 0.2775 - val_categorical_accuracy: 0.8979
# Epoch 134/200
# 20576/20576 [==============================] - 11s 551us/step - loss: 0.2630 - categorical_accuracy: 0.9043 - val_loss: 0.2762 - val_categorical_accuracy: 0.8981
# Epoch 135/200
# 20576/20576 [==============================] - 11s 557us/step - loss: 0.2619 - categorical_accuracy: 0.9033 - val_loss: 0.2736 - val_categorical_accuracy: 0.9003
# Epoch 136/200
# 20576/20576 [==============================] - 12s 559us/step - loss: 0.2622 - categorical_accuracy: 0.9047 - val_loss: 0.2703 - val_categorical_accuracy: 0.8995
# Epoch 137/200
# 20576/20576 [==============================] - 11s 555us/step - loss: 0.2596 - categorical_accuracy: 0.9047 - val_loss: 0.2731 - val_categorical_accuracy: 0.8970
# Epoch 138/200
# 20576/20576 [==============================] - 12s 570us/step - loss: 0.2595 - categorical_accuracy: 0.9065 - val_loss: 0.2737 - val_categorical_accuracy: 0.8981
# Epoch 139/200
# 20576/20576 [==============================] - 11s 558us/step - loss: 0.2563 - categorical_accuracy: 0.9056 - val_loss: 0.2668 - val_categorical_accuracy: 0.9022
# Epoch 140/200
# 20576/20576 [==============================] - 11s 556us/step - loss: 0.2559 - categorical_accuracy: 0.9056 - val_loss: 0.2723 - val_categorical_accuracy: 0.8974
# Epoch 141/200
# 20576/20576 [==============================] - 12s 562us/step - loss: 0.2546 - categorical_accuracy: 0.9071 - val_loss: 0.2636 - val_categorical_accuracy: 0.9018
# Epoch 142/200
# 20576/20576 [==============================] - 11s 535us/step - loss: 0.2542 - categorical_accuracy: 0.9067 - val_loss: 0.2646 - val_categorical_accuracy: 0.8999
# Epoch 143/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.2526 - categorical_accuracy: 0.9069 - val_loss: 0.2624 - val_categorical_accuracy: 0.9020
# Epoch 144/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.2527 - categorical_accuracy: 0.9068 - val_loss: 0.2633 - val_categorical_accuracy: 0.9016
# Epoch 145/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.2507 - categorical_accuracy: 0.9068 - val_loss: 0.2652 - val_categorical_accuracy: 0.9014
# Epoch 146/200
# 20576/20576 [==============================] - 11s 542us/step - loss: 0.2492 - categorical_accuracy: 0.9090 - val_loss: 0.2618 - val_categorical_accuracy: 0.9030
# Epoch 147/200
# 20576/20576 [==============================] - 11s 524us/step - loss: 0.2487 - categorical_accuracy: 0.9080 - val_loss: 0.2655 - val_categorical_accuracy: 0.9001
# Epoch 148/200
# 20576/20576 [==============================] - 11s 514us/step - loss: 0.2483 - categorical_accuracy: 0.9091 - val_loss: 0.2674 - val_categorical_accuracy: 0.8989
# Epoch 149/200
# 20576/20576 [==============================] - 11s 527us/step - loss: 0.2475 - categorical_accuracy: 0.9086 - val_loss: 0.2624 - val_categorical_accuracy: 0.9032
# Epoch 150/200
# 20576/20576 [==============================] - 11s 538us/step - loss: 0.2451 - categorical_accuracy: 0.9101 - val_loss: 0.2566 - val_categorical_accuracy: 0.9040
# Epoch 151/200
# 20576/20576 [==============================] - 11s 548us/step - loss: 0.2426 - categorical_accuracy: 0.9106 - val_loss: 0.2554 - val_categorical_accuracy: 0.9036
# Epoch 152/200
# 20576/20576 [==============================] - 12s 600us/step - loss: 0.2430 - categorical_accuracy: 0.9103 - val_loss: 0.2575 - val_categorical_accuracy: 0.9055
# Epoch 153/200
# 20576/20576 [==============================] - 12s 587us/step - loss: 0.2425 - categorical_accuracy: 0.9097 - val_loss: 0.2584 - val_categorical_accuracy: 0.9045
# Epoch 154/200
# 20576/20576 [==============================] - 13s 647us/step - loss: 0.2408 - categorical_accuracy: 0.9118 - val_loss: 0.2571 - val_categorical_accuracy: 0.9065
# Epoch 155/200
# 20576/20576 [==============================] - 12s 599us/step - loss: 0.2389 - categorical_accuracy: 0.9121 - val_loss: 0.2531 - val_categorical_accuracy: 0.9071
# Epoch 156/200
# 20576/20576 [==============================] - 11s 533us/step - loss: 0.2384 - categorical_accuracy: 0.9121 - val_loss: 0.2529 - val_categorical_accuracy: 0.9040
# Epoch 157/200
# 20576/20576 [==============================] - 11s 525us/step - loss: 0.2375 - categorical_accuracy: 0.9136 - val_loss: 0.2541 - val_categorical_accuracy: 0.9012
# Epoch 158/200
# 20576/20576 [==============================] - 11s 523us/step - loss: 0.2361 - categorical_accuracy: 0.9143 - val_loss: 0.2497 - val_categorical_accuracy: 0.9049
# Epoch 159/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.2365 - categorical_accuracy: 0.9123 - val_loss: 0.2490 - val_categorical_accuracy: 0.9098
# Epoch 160/200
# 20576/20576 [==============================] - 11s 526us/step - loss: 0.2348 - categorical_accuracy: 0.9138 - val_loss: 0.2612 - val_categorical_accuracy: 0.8991
# Epoch 161/200
# 20576/20576 [==============================] - 11s 526us/step - loss: 0.2341 - categorical_accuracy: 0.9139 - val_loss: 0.2451 - val_categorical_accuracy: 0.9080
# Epoch 162/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.2319 - categorical_accuracy: 0.9149 - val_loss: 0.2473 - val_categorical_accuracy: 0.9077
# Epoch 163/200
# 20576/20576 [==============================] - 11s 529us/step - loss: 0.2319 - categorical_accuracy: 0.9143 - val_loss: 0.2441 - val_categorical_accuracy: 0.9080
# Epoch 164/200
# 20576/20576 [==============================] - 11s 536us/step - loss: 0.2303 - categorical_accuracy: 0.9147 - val_loss: 0.2498 - val_categorical_accuracy: 0.9049
# Epoch 165/200
# 20576/20576 [==============================] - 11s 532us/step - loss: 0.2319 - categorical_accuracy: 0.9140 - val_loss: 0.2438 - val_categorical_accuracy: 0.9067
# Epoch 166/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.2287 - categorical_accuracy: 0.9148 - val_loss: 0.2442 - val_categorical_accuracy: 0.9092
# Epoch 167/200
# 20576/20576 [==============================] - 11s 541us/step - loss: 0.2273 - categorical_accuracy: 0.9156 - val_loss: 0.2390 - val_categorical_accuracy: 0.9082
# Epoch 168/200
# 20576/20576 [==============================] - 11s 522us/step - loss: 0.2263 - categorical_accuracy: 0.9163 - val_loss: 0.2410 - val_categorical_accuracy: 0.9069
# Epoch 169/200
# 20576/20576 [==============================] - 11s 535us/step - loss: 0.2269 - categorical_accuracy: 0.9156 - val_loss: 0.2414 - val_categorical_accuracy: 0.9114
# Epoch 170/200
# 20576/20576 [==============================] - 11s 548us/step - loss: 0.2251 - categorical_accuracy: 0.9164 - val_loss: 0.2460 - val_categorical_accuracy: 0.9063
# Epoch 171/200
# 20576/20576 [==============================] - 11s 530us/step - loss: 0.2249 - categorical_accuracy: 0.9174 - val_loss: 0.2405 - val_categorical_accuracy: 0.9088
# Epoch 172/200
# 20576/20576 [==============================] - 11s 525us/step - loss: 0.2235 - categorical_accuracy: 0.9157 - val_loss: 0.2348 - val_categorical_accuracy: 0.9115
# Epoch 173/200
# 20576/20576 [==============================] - 11s 554us/step - loss: 0.2226 - categorical_accuracy: 0.9158 - val_loss: 0.2349 - val_categorical_accuracy: 0.9112
# Epoch 174/200
# 20576/20576 [==============================] - 13s 623us/step - loss: 0.2209 - categorical_accuracy: 0.9177 - val_loss: 0.2353 - val_categorical_accuracy: 0.9117
# Epoch 175/200
# 20576/20576 [==============================] - 13s 624us/step - loss: 0.2213 - categorical_accuracy: 0.9171 - val_loss: 0.2336 - val_categorical_accuracy: 0.9143
# Epoch 176/200
# 20576/20576 [==============================] - 13s 638us/step - loss: 0.2201 - categorical_accuracy: 0.9186 - val_loss: 0.2417 - val_categorical_accuracy: 0.9069
# Epoch 177/200
# 20576/20576 [==============================] - 12s 591us/step - loss: 0.2198 - categorical_accuracy: 0.9194 - val_loss: 0.2343 - val_categorical_accuracy: 0.9110
# Epoch 178/200
# 20576/20576 [==============================] - 12s 564us/step - loss: 0.2187 - categorical_accuracy: 0.9183 - val_loss: 0.2352 - val_categorical_accuracy: 0.9110
# Epoch 179/200
# 20576/20576 [==============================] - 11s 551us/step - loss: 0.2174 - categorical_accuracy: 0.9180 - val_loss: 0.2338 - val_categorical_accuracy: 0.9135
# Epoch 180/200
# 20576/20576 [==============================] - 11s 553us/step - loss: 0.2174 - categorical_accuracy: 0.9188 - val_loss: 0.2301 - val_categorical_accuracy: 0.9125
# Epoch 181/200
# 20576/20576 [==============================] - 11s 540us/step - loss: 0.2159 - categorical_accuracy: 0.9182 - val_loss: 0.2273 - val_categorical_accuracy: 0.9131
# Epoch 182/200
# 20576/20576 [==============================] - 11s 550us/step - loss: 0.2139 - categorical_accuracy: 0.9212 - val_loss: 0.2298 - val_categorical_accuracy: 0.9145
# Epoch 183/200
# 20576/20576 [==============================] - 9s 459us/step - loss: 0.2141 - categorical_accuracy: 0.9198 - val_loss: 0.2254 - val_categorical_accuracy: 0.9170
# Epoch 184/200
# 20576/20576 [==============================] - 8s 408us/step - loss: 0.2121 - categorical_accuracy: 0.9217 - val_loss: 0.2273 - val_categorical_accuracy: 0.9139
# Epoch 185/200
# 20576/20576 [==============================] - 8s 401us/step - loss: 0.2127 - categorical_accuracy: 0.9212 - val_loss: 0.2257 - val_categorical_accuracy: 0.9137
# Epoch 186/200
# 20576/20576 [==============================] - 8s 405us/step - loss: 0.2117 - categorical_accuracy: 0.9204 - val_loss: 0.2238 - val_categorical_accuracy: 0.9154 loss: 0.2133 - ca
# Epoch 187/200
# 20576/20576 [==============================] - 8s 388us/step - loss: 0.2120 - categorical_accuracy: 0.9207 - val_loss: 0.2259 - val_categorical_accuracy: 0.9162
# Epoch 188/200
# 20576/20576 [==============================] - 8s 385us/step - loss: 0.2104 - categorical_accuracy: 0.9232 - val_loss: 0.2236 - val_categorical_accuracy: 0.9145
# Epoch 189/200
# 20576/20576 [==============================] - 8s 397us/step - loss: 0.2093 - categorical_accuracy: 0.9202 - val_loss: 0.2220 - val_categorical_accuracy: 0.9152
# Epoch 190/200
# 20576/20576 [==============================] - 8s 391us/step - loss: 0.2077 - categorical_accuracy: 0.9226 - val_loss: 0.2263 - val_categorical_accuracy: 0.9110
# Epoch 191/200
# 20576/20576 [==============================] - 10s 466us/step - loss: 0.2073 - categorical_accuracy: 0.9233 - val_loss: 0.2232 - val_categorical_accuracy: 0.9125
# Epoch 192/200
# 20576/20576 [==============================] - 9s 441us/step - loss: 0.2066 - categorical_accuracy: 0.9231 - val_loss: 0.2199 - val_categorical_accuracy: 0.9160
# Epoch 193/200
# 20576/20576 [==============================] - 9s 423us/step - loss: 0.2062 - categorical_accuracy: 0.9231 - val_loss: 0.2243 - val_categorical_accuracy: 0.9149
# Epoch 194/200
# 20576/20576 [==============================] - 9s 447us/step - loss: 0.2068 - categorical_accuracy: 0.9217 - val_loss: 0.2183 - val_categorical_accuracy: 0.9172
# Epoch 195/200
# 20576/20576 [==============================] - 8s 397us/step - loss: 0.2054 - categorical_accuracy: 0.9233 - val_loss: 0.2203 - val_categorical_accuracy: 0.9182
# Epoch 196/200
# 20576/20576 [==============================] - 8s 374us/step - loss: 0.2030 - categorical_accuracy: 0.9246 - val_loss: 0.2160 - val_categorical_accuracy: 0.9176
# Epoch 197/200
# 20576/20576 [==============================] - 8s 398us/step - loss: 0.2032 - categorical_accuracy: 0.9249 - val_loss: 0.2269 - val_categorical_accuracy: 0.9119
# Epoch 198/200
# 20576/20576 [==============================] - 8s 384us/step - loss: 0.2024 - categorical_accuracy: 0.9253 - val_loss: 0.2220 - val_categorical_accuracy: 0.9139
# Epoch 199/200
# 20576/20576 [==============================] - 8s 387us/step - loss: 0.2018 - categorical_accuracy: 0.9251 - val_loss: 0.2152 - val_categorical_accuracy: 0.9170
# Epoch 200/200
# 20576/20576 [==============================] - 8s 387us/step - loss: 0.1997 - categorical_accuracy: 0.9259 - val_loss: 0.2236 - val_categorical_accuracy: 0.9152

# %%
# summarize history for accuracy
plt.figure(0,figsize=(10, 8))
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(0,figsize=(10, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Evaluate
predictions = model.predict_classes(testX[:,:,1:])

# %%
scores = model.evaluate(testX[:,:,1:], testY, verbose=2)
print(scores)
# Out:
# [6.292008082426659, 0.24975170277763395]

# %%
timeTest = np.array(testX[:,:,0])
forceLeftTest = np.array(testX[:,:,1])
forceRightTest = np.array(testX[:,:,9])
predTest = np.array(predictions+2)
realTest = np.array(np.argmax(testY, axis=2)+2)
result = np.concatenate((timeTest,forceLeftTest, forceRightTest, predTest, realTest), axis=1)

# %%
ind=np.argsort(result[:,0])
result2 = result[ind]

# %%
plt.figure(0,figsize=(20, 5))
color = {2:'red',3:'orange',4:'pink', 5:'blue'}
plt.title('Force Left(Predictions)')
for i in range(2,6):
    classResult = result[result[:,3]==i]
    plt.scatter(classResult[:,0],classResult[:,1],c =color[i],label='Gear ' + str(i))
    plt.legend()
plt.show()

plt.figure(0,figsize=(20, 5))
color = {2:'red',3:'orange',4:'pink', 5:'blue'}
plt.title('Force Left(True Class)')
for i in range(2,6):
    classRealResult = result[result[:,4]==i]
    plt.scatter(classRealResult[:,0],classRealResult[:,1],c =color[i],label='Gear ' + str(i))
    plt.legend()
plt.show()

plt.figure(0,figsize=(20, 5))
plt.title('Force Right(Predictions)')
for i in range(2,6):
    classResult = result[result[:,3]==i]
    plt.scatter(classResult[:,0],classResult[:,2],c =color[i],label='Gear ' + str(i))
    plt.legend()
plt.show()

plt.figure(0,figsize=(20, 5))
color = {2:'red',3:'orange',4:'pink', 5:'blue'}
plt.title('Force Right(True Class)')
for i in range(2,6):
    classRealResult = result[result[:,4]==i]
    plt.scatter(classRealResult[:,0],classRealResult[:,2],c =color[i],label='Gear ' + str(i))
    plt.legend()
plt.show()

# %%
for i in range(2,6):
    classPredResult = result[result[:,3]==i]
    classRealResult = result[result[:,4]==i]
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20,8))
    
    ax1.set_title('Force Left for Gear '+str(i) +': Real vs Prediction') 
    ax1.scatter(classRealResult[:,0],classRealResult[:,1],c ='red',label='Real Gear ' + str(i))
    ax1.scatter(classPredResult[:,0],classPredResult[:,1],c ='blue',label='Predicted Gear ' + str(i))
    ax1.legend(loc="upper right")
    
    ax2.set_title('Force Right for Gear '+str(i) +': Real vs Prediction') 
    ax2.scatter(classRealResult[:,0],classRealResult[:,2],c ='red',label='Real Gear ' + str(i))
    ax2.scatter(classPredResult[:,0],classPredResult[:,2],c ='blue',label='Predicted Gear ' + str(i))
    ax2.legend(loc="upper right")
plt.show()
